# %% [markdown]
# ##### Importing Modules

# %%
import pandas as pd
import gzip

# %%
import matplotlib.pyplot as plt

# %%
import datetime
import calendar

# %%
import numpy as np

# %%
from string import punctuation

# %%
from __future__ import division

# %%
from nltk.tokenize import word_tokenize 
from nltk.tokenize import sent_tokenize
from nltk.tokenize import regexp_tokenize

# %%
import re

# %%
# data visualization
# pip install seaborn
import seaborn as sns

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style
plt.style.use('fivethirtyeight')

# %% [markdown]
# # Start of Data Munging Section

# %% [markdown]
# ###### Function to GUnzip a File

# %%
def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

# %% [markdown]
# ###### Function to return a Dataframe from a JSON - Gzip file

# %%
def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

# %% [markdown]
# ###### Reading the Reviews into DataFrames

# %%
df_IV = getDF('reviews_Amazon_Instant_Video_5.json.gz')
df_AA = getDF('reviews_Apps_for_Android_5.json.gz')
df_AU = getDF('reviews_Automotive_5.json.gz')
df_BA = getDF('reviews_Baby_5.json.gz')
df_BE = getDF('reviews_Beauty_5.json.gz')
df_BO = getDF('reviews_Books_5.json.gz')
df_CV = getDF('reviews_CDs_and_Vinyl_5.json.gz')
df_CP = getDF('reviews_Cell_Phones_and_Accessories_5.json.gz')
df_CJ = getDF('reviews_Clothing_Shoes_and_Jewelry_5.json.gz')
df_DM = getDF('reviews_Digital_Music_5.json.gz')
df_EL = getDF('reviews_Electronics_5.json.gz')
df_GG = getDF('reviews_Grocery_and_Gourmet_Food_5.json.gz')
df_HP = getDF('reviews_Health_and_Personal_Care_5.json.gz')
df_HK = getDF('reviews_Home_and_Kitchen_5.json.gz')
df_KS = getDF('reviews_Kindle_Store_5.json.gz')
df_MT = getDF('reviews_Movies_and_TV_5.json.gz')
df_MI = getDF('reviews_Musical_Instruments_5.json.gz')
df_OP = getDF('reviews_Office_Products_5.json.gz')
df_LG = getDF('reviews_Patio_Lawn_and_Garden_5.json.gz')
df_PS = getDF('reviews_Pet_Supplies_5.json.gz')
df_SO = getDF('reviews_Sports_and_Outdoors_5.json.gz')
df_TH = getDF('reviews_Tools_and_Home_Improvement_5.json.gz')
df_TG = getDF('reviews_Toys_and_Games_5.json.gz')
df_VG = getDF('reviews_Video_Games_5.json.gz')

# %% [markdown]
# ###### Adding the Product Type Column to each DataFrame

# %%
df_IV['ProductType'] = 'Instant Video'
df_AA['ProductType'] = 'Android Apps'
df_AU['ProductType'] = 'Automotive'
df_BA['ProductType'] = 'Baby'
df_BE['ProductType'] = 'Beauty'
df_BO['ProductType'] = 'Books'
df_CV['ProductType'] = 'CDs_and_Vinyl'
df_CP['ProductType'] = 'Cell_Phones_and_Accessories'
df_CJ['ProductType'] = 'Clothing_Shoes_and_Jewelry'
df_DM['ProductType'] = 'Digital_Music'
df_EL['ProductType'] = 'Electronics'
df_GG['ProductType'] = 'Grocery_and_Gourmet_Food'
df_HP['ProductType'] = 'Health_and_Personal_Care'
df_HK['ProductType'] = 'Home_and_Kitchen'
df_KS['ProductType'] = 'Kindle_Store'
df_MT['ProductType'] = 'Movies_and_TV'
df_MI['ProductType'] = 'Musical_Instruments'
df_OP['ProductType'] = 'Office_Products'
df_LG['ProductType'] = 'Patio_Lawn_and_Garden'
df_PS['ProductType'] = 'Pet_Supplies'
df_SO['ProductType'] = 'Sports_and_Outdoors'
df_TH['ProductType'] = 'Tools_and_Home_Improvement'
df_TG['ProductType'] = 'Toys_and_Games'
df_VG['ProductType'] = 'Video_Games'

# %% [markdown]
# ###### Adding individual DFs to AmazonReviewsDataFrame List

# %%
df_AzReviews =[]
df_AzReviews.append(df_IV)
df_AzReviews.append(df_AA)
df_AzReviews.append(df_AU) 
df_AzReviews.append(df_BA) 
df_AzReviews.append(df_BE) 
df_AzReviews.append(df_BO) 
df_AzReviews.append(df_CV) 
df_AzReviews.append(df_CP) 
df_AzReviews.append(df_CJ) 
df_AzReviews.append(df_DM) 
df_AzReviews.append(df_EL) 
df_AzReviews.append(df_GG)
df_AzReviews.append(df_HP) 
df_AzReviews.append(df_HK) 
df_AzReviews.append(df_KS) 
df_AzReviews.append(df_MT)
df_AzReviews.append(df_MI) 
df_AzReviews.append(df_OP)
df_AzReviews.append(df_LG) 
df_AzReviews.append(df_PS) 
df_AzReviews.append(df_SO)
df_AzReviews.append(df_TH)
df_AzReviews.append(df_TG)
df_AzReviews.append(df_VG)

print(df_AzReviews[0].info())  
print(df_AzReviews[23].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37126 entries, 0 to 37125
# Data columns (total 10 columns):
# overall           37126 non-null float64
# unixReviewTime    37126 non-null int64
# reviewTime        37126 non-null object
# summary           37126 non-null object
# reviewerID        37126 non-null object
# helpful           37126 non-null object
# asin              37126 non-null object
# reviewText        37126 non-null object
# reviewerName      36797 non-null object
# ProductType       37126 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 3.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 231780 entries, 0 to 231779
# Data columns (total 10 columns):
# overall           231780 non-null float64
# unixReviewTime    231780 non-null int64
# reviewTime        231780 non-null object
# summary           231780 non-null object
# reviewerID        231780 non-null object
# helpful           231780 non-null object
# asin              231780 non-null object
# reviewText        231780 non-null object
# reviewerName      228967 non-null object
# ProductType       231780 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 19.5+ MB
# None

# %% [markdown]
# ###### Add Column Names to Ratings Dataframe since it is missing the Header

# %%
RatingColumnNames = ['reviewerID','asin','overall','unixReviewTime']

# %% [markdown]
# ###### Reading the Ratings into DataFrames

# %%
df_RT_IV = pd.read_csv('ratings_Amazon_Instant_Video.csv', header=0, names=RatingColumnNames)
df_RT_AA = pd.read_csv('ratings_Apps_for_Android.csv',  header=0, names=RatingColumnNames)
df_RT_AU = pd.read_csv('ratings_Automotive.csv',  header=0, names=RatingColumnNames)
df_RT_BA = pd.read_csv('ratings_Baby.csv', header=0, names=RatingColumnNames)
df_RT_BE = pd.read_csv('ratings_Beauty.csv', header=0, names=RatingColumnNames)
df_RT_BO = pd.read_csv('ratings_Books.csv', header=0, names=RatingColumnNames)
df_RT_CV = pd.read_csv('ratings_CDs_and_Vinyl.csv', header=0, names=RatingColumnNames)
df_RT_CP = pd.read_csv('ratings_Cell_Phones_and_Accessories.csv', header=0, names=RatingColumnNames)
df_RT_CJ = pd.read_csv('ratings_Clothing_Shoes_and_Jewelry.csv', header=0, names=RatingColumnNames)
df_RT_DM = pd.read_csv('ratings_Digital_Music.csv', header=0, names=RatingColumnNames)
df_RT_EL = pd.read_csv('ratings_Electronics.csv', header=0, names=RatingColumnNames)
df_RT_GG = pd.read_csv('ratings_Grocery_and_Gourmet_Food.csv', header=0, names=RatingColumnNames)
df_RT_HP = pd.read_csv('ratings_Health_and_Personal_Care.csv', header=0, names=RatingColumnNames)
df_RT_HK = pd.read_csv('ratings_Home_and_Kitchen.csv', header=0, names=RatingColumnNames)
df_RT_KS = pd.read_csv('ratings_Kindle_Store.csv', header=0, names=RatingColumnNames)
df_RT_MT = pd.read_csv('ratings_Movies_and_TV.csv', header=0, names=RatingColumnNames)
df_RT_MI = pd.read_csv('ratings_Musical_Instruments.csv', header=0, names=RatingColumnNames)
df_RT_OP = pd.read_csv('ratings_Office_Products.csv', header=0, names=RatingColumnNames)
df_RT_LG = pd.read_csv('ratings_Patio_Lawn_and_Garden.csv', header=0, names=RatingColumnNames)
df_RT_PS = pd.read_csv('ratings_Pet_Supplies.csv', header=0, names=RatingColumnNames)
df_RT_SO = pd.read_csv('ratings_Sports_and_Outdoors.csv', header=0, names=RatingColumnNames)
df_RT_TH = pd.read_csv('ratings_Tools_and_Home_Improvement.csv', header=0, names=RatingColumnNames)
df_RT_TG = pd.read_csv('ratings_Toys_and_Games.csv', header=0, names=RatingColumnNames)
df_RT_VG = pd.read_csv('ratings_Video_Games.csv', header=0, names=RatingColumnNames)

# %% [markdown]
# ###### Adding the Product Type Column to each DataFrame

# %%
df_RT_IV['ProductType'] = 'Instant Video'
df_RT_AA['ProductType'] = 'Android Apps'
df_RT_AU['ProductType'] = 'Automotive'
df_RT_BA['ProductType'] = 'Baby'
df_RT_BE['ProductType'] = 'Beauty'
df_RT_BO['ProductType'] = 'Books'
df_RT_CV['ProductType'] = 'CDs_and_Vinyl'
df_RT_CP['ProductType'] = 'Cell_Phones_and_Accessories'
df_RT_CJ['ProductType'] = 'Clothing_Shoes_and_Jewelry'
df_RT_DM['ProductType'] = 'Digital_Music'
df_RT_EL['ProductType'] = 'Electronics'
df_RT_GG['ProductType'] = 'Grocery_and_Gourmet_Food'
df_RT_HP['ProductType'] = 'Health_and_Personal_Care'
df_RT_HK['ProductType'] = 'Home_and_Kitchen'
df_RT_KS['ProductType'] = 'Kindle_Store'
df_RT_MT['ProductType'] = 'Movies_and_TV'
df_RT_MI['ProductType'] = 'Musical_Instruments'
df_RT_OP['ProductType'] = 'Office_Products'
df_RT_LG['ProductType'] = 'Patio_Lawn_and_Garden'
df_RT_PS['ProductType'] = 'Pet_Supplies'
df_RT_SO['ProductType'] = 'Sports_and_Outdoors'
df_RT_TH['ProductType'] = 'Tools_and_Home_Improvement'
df_RT_TG['ProductType'] = 'Toys_and_Games'
df_RT_VG['ProductType'] = 'Video_Games'

# %% [markdown]
# ###### Adding individual DFs to AmazonRatingsDataFrame List

# %%
df_AzRatings =[]
df_AzRatings.append(df_RT_IV)
df_AzRatings.append(df_RT_AA)
df_AzRatings.append(df_RT_AU) 
df_AzRatings.append(df_RT_BA) 
df_AzRatings.append(df_RT_BE) 
df_AzRatings.append(df_RT_BO) 
df_AzRatings.append(df_RT_CV) 
df_AzRatings.append(df_RT_CP) 
df_AzRatings.append(df_RT_CJ) 
df_AzRatings.append(df_RT_DM) 
df_AzRatings.append(df_RT_EL) 
df_AzRatings.append(df_RT_GG)
df_AzRatings.append(df_RT_HP) 
df_AzRatings.append(df_RT_HK) 
df_AzRatings.append(df_RT_KS) 
df_AzRatings.append(df_RT_MT)
df_AzRatings.append(df_RT_MI) 
df_AzRatings.append(df_RT_OP)
df_AzRatings.append(df_RT_LG) 
df_AzRatings.append(df_RT_PS) 
df_AzRatings.append(df_RT_SO)
df_AzRatings.append(df_RT_TH)
df_AzRatings.append(df_RT_TG)
df_AzRatings.append(df_RT_VG)

print(df_AzRatings[0].info())  
print(df_AzRatings[23].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583932 entries, 0 to 583931
# Data columns (total 5 columns):
# reviewerID        583932 non-null object
# asin              583932 non-null object
# overall           583932 non-null float64
# unixReviewTime    583932 non-null int64
# ProductType       583932 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 22.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1324752 entries, 0 to 1324751
# Data columns (total 5 columns):
# reviewerID        1324752 non-null object
# asin              1324752 non-null object
# overall           1324752 non-null float64
# unixReviewTime    1324752 non-null int64
# ProductType       1324752 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 50.5+ MB
# None

# %% [markdown]
# ###### Printing Reviews and Ratings Dataframes

# %%
print(df_AzReviews[23].head())
# Out:
#    overall  unixReviewTime   reviewTime  \
# 0      1.0      1341792000   07 9, 2012
# 1      4.0      1372550400  06 30, 2013
# 2      1.0      1403913600  06 28, 2014
# 3      3.0      1315958400  09 14, 2011
# 4      4.0      1308009600  06 14, 2011
#
#                                            summary      reviewerID  helpful  \
# 0         Pay to unlock content? I don't think so.  A2HD75EMZR8QLN  [8, 12]
# 1                                  Good rally game  A3UR8NLLY1ZHCX   [0, 0]
# 2                                        Wrong key  A1INA0F5CWW3J4   [0, 0]
# 3  awesome game, if it did not crash frequently !!  A1DLMTOTHQ4AST  [7, 10]
# 4                                           DIRT 3  A361M14PU2GUEG   [2, 2]
#
#          asin                                         reviewText  \
# 0  0700099867  Installing the game was a struggle (because of...
# 1  0700099867  If you like rally cars get this game you will ...
# 2  0700099867  1st shipment received a book instead of the ga...
# 3  0700099867  I got this version instead of the PS3 version,...
# 4  0700099867  I had Dirt 2 on Xbox 360 and it was an okay ga...
#
#                          reviewerName  ProductType
# 0                                 123  Video_Games
# 1  Alejandro Henao "Electronic Junky"  Video_Games
# 2          Amazon Shopper "Mr.Repsol"  Video_Games
# 3                            ampgreen  Video_Games
# 4        Angry Ryan "Ryan A. Forrest"  Video_Games

# %%
print(df_AzRatings[23].head())
# Out:
#        reviewerID        asin  overall  unixReviewTime  ProductType
# 0  A24SSUT5CSW8BH  0078764343      5.0      1377302400  Video_Games
# 1   AK3V0HEBJMQ7J  0078764343      4.0      1372896000  Video_Games
# 2  A10BECPH7W8HM7  043933702X      5.0      1404950400  Video_Games
# 3  A2PRV9OULX1TWP  043933702X      5.0      1386115200  Video_Games
# 4   AE7GUHCDQQ4UI  043933702X      1.0      1366156800  Video_Games

# %% [markdown]
# ###### Dataframe df_AzReviews[23] and df_AzRatings[23] Before dropna

# %%
df_AzReviews[23].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 231780 entries, 0 to 231779
# Data columns (total 10 columns):
# overall           231780 non-null float64
# unixReviewTime    231780 non-null int64
# reviewTime        231780 non-null object
# summary           231780 non-null object
# reviewerID        231780 non-null object
# helpful           231780 non-null object
# asin              231780 non-null object
# reviewText        231780 non-null object
# reviewerName      228967 non-null object
# ProductType       231780 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 19.5+ MB

# %%
df_AzRatings[23].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1324752 entries, 0 to 1324751
# Data columns (total 5 columns):
# reviewerID        1324752 non-null object
# asin              1324752 non-null object
# overall           1324752 non-null float64
# unixReviewTime    1324752 non-null int64
# ProductType       1324752 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 50.5+ MB

# %% [markdown]
# ###### Dataframe df_AzReviews[23] and df_AzRatings[23] After dropna - Shows no change for Ratings row numbers

# %%
df_AzReviews[23].dropna(how="any",inplace = True)
df_AzReviews[23].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228967 entries, 0 to 231779
# Data columns (total 10 columns):
# overall           228967 non-null float64
# unixReviewTime    228967 non-null int64
# reviewTime        228967 non-null object
# summary           228967 non-null object
# reviewerID        228967 non-null object
# helpful           228967 non-null object
# asin              228967 non-null object
# reviewText        228967 non-null object
# reviewerName      228967 non-null object
# ProductType       228967 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 19.2+ MB

# %%
df_AzRatings[23].dropna(how="any",inplace = True)
df_AzRatings[23].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1324752 entries, 0 to 1324751
# Data columns (total 5 columns):
# reviewerID        1324752 non-null object
# asin              1324752 non-null object
# overall           1324752 non-null float64
# unixReviewTime    1324752 non-null int64
# ProductType       1324752 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 60.6+ MB

# %% [markdown]
# ###### Dataframe df_AzReviews -  running the dropna method on the list of DFs

# %%
for i in range(24):
    df_AzReviews[i].dropna(how="any",inplace = True)

# %% [markdown]
# ###### Dataframe df_AzRatings -  running the dropna method on the list of DFs

# %%
for i in range(24):
    df_AzRatings[i].dropna(how="any",inplace = True)

# %% [markdown]
# ###### Printing Reviews & Rating Dataframe Heads to check data integrity

# %%
print(df_AzReviews[0].head())
print(df_AzRatings[0].head())
# Out:
#    overall  unixReviewTime   reviewTime                         summary  \
# 0      2.0      1399075200   05 3, 2014      A little bit boring for me
# 1      5.0      1346630400   09 3, 2012           Excellent Grown Up TV
# 2      1.0      1381881600  10 16, 2013           Way too boring for me
# 3      4.0      1383091200  10 30, 2013     Robson Green is mesmerizing
# 4      5.0      1234310400  02 11, 2009  Robson green and great writing
#
#        reviewerID helpful        asin  \
# 0  A11N155CW1UV02  [0, 0]  B000H00VBQ
# 1  A3BC8O2KCL29V2  [0, 0]  B000H00VBQ
# 2   A60D5HQFOTSOM  [0, 1]  B000H00VBQ
# 3  A1RJPIGRSNX4PW  [0, 0]  B000H00VBQ
# 4  A16XRPF40679KG  [1, 1]  B000H00VBQ
#
#                                           reviewText  \
# 0  I had big expectations because I love English ...
# 1  I highly recommend this series. It is a must f...
# 2  This one is a real snoozer. Don't believe anyt...
# 3  Mysteries are interesting.  The tension betwee...
# 4  This show always is excellent, as far as briti...
#
#                      reviewerName    ProductType
# 0                        AdrianaM  Instant Video
# 1                         Carol T  Instant Video
# 2  Daniel Cooper "dancoopermedia"  Instant Video
# 3                  J. Kaplan "JJ"  Instant Video
# 4                   Michael Dobey  Instant Video
#        reviewerID        asin  overall  unixReviewTime    ProductType
# 0   AGZ8SM1BGK3CK  B000GFDAUG      5.0      1198195200  Instant Video
# 1  A2VHZ21245KBT7  B000GIOPK2      4.0      1215388800  Instant Video
# 2   ACX8YW2D5EGP6  B000GIOPK2      4.0      1185840000  Instant Video
# 3   A9RNMO9MUSMTJ  B000GIOPK2      2.0      1281052800  Instant Video
# 4  A3STFVPM8NHJ7B  B000GIOPK2      5.0      1203897600  Instant Video

# %% [markdown]
# ###### Printing Reviews & Rating Dataframe Tails to check data integrity

# %%
print(df_AzReviews[0].tail())
print(df_AzRatings[0].tail())
# Out:
#        overall  unixReviewTime   reviewTime  \
# 37121      5.0      1405728000  07 19, 2014
# 37122      5.0      1405296000  07 14, 2014
# 37123      3.0      1405296000  07 14, 2014
# 37124      4.0      1405296000  07 14, 2014
# 37125      3.0      1405468800  07 16, 2014
#
#                                                  summary      reviewerID  \
# 37121                                      Great Series!  A1ELO9LMSE1CQ7
# 37122  Forget the Vampire Diaries -- This is a REAL V...   AGOEKVIJV9UX6
# 37123  It's only the first episode so I'm not real su...  A3I291BE0RNZCU
# 37124  and that is good. The accents are a bit much h...  A1MNITZRYU71IO
# 37125                  I may have paid towatch the pilot  A1XMHK9HN5MW2H
#
#         helpful        asin  \
# 37121    [0, 0]  B00LPWPMCS
# 37122  [13, 15]  B00LPWPMCS
# 37123    [0, 2]  B00LPWPMCS
# 37124    [1, 1]  B00LPWPMCS
# 37125    [3, 4]  B00LPWPMCS
#
#                                               reviewText  \
# 37121  I love the books! The show is amazing so far. ...
# 37122  "The Strain" has potential to be an excellent ...
# 37123  I'm not real sure on how, I should rate this s...
# 37124  episode one so far makes me want to watch more...
# 37125  I watched the pilot.  I guess I've just seen t...
#
#                   reviewerName    ProductType
# 37121                    Mpr90  Instant Video
# 37122             Mr. Markster  Instant Video
# 37123      Rating My Best Pick  Instant Video
# 37124  Sherry "trying in ohio"  Instant Video
# 37125     Victoria J. Dennison  Instant Video
#             reviewerID        asin  overall  unixReviewTime    ProductType
# 583927   A9MBSKL8LTFN9  B00LTMHUW4      5.0      1405987200  Instant Video
# 583928  A3U3RFL0XE4F7V  B00LTMJ29S      4.0      1405382400  Instant Video
# 583929   AEO407GROR6JB  B00LU8ONBI      1.0      1405468800  Instant Video
# 583930  A2YXWWVABHWIXN  B00LU8ONBI      5.0      1405728000  Instant Video
# 583931   ANZJEQZRYUCBC  B00LXQXLGU      4.0      1405900800  Instant Video

# %% [markdown]
# # End of Data Munging Section

# %% [markdown]
# # Start of Data Analysis Section on Smaller DataSet

# %% [markdown]
# ###### Splitting DateTimestamp field

# %%
date = datetime.datetime.utcfromtimestamp(1202256000)
print(date)
print(date.year)
print(date.month)
print(date.day)
# Out:
# 2008-02-06 00:00:00
# 2008
# 2
# 6

# %% [markdown]
# ###### Checking the 'reviewText' field in the Review dataframe

# %%
print(df_AzReviews[0]['reviewText'].head())
# Out:
# 0    I had big expectations because I love English ...
# 1    I highly recommend this series. It is a must f...
# 2    This one is a real snoozer. Don't believe anyt...
# 3    Mysteries are interesting.  The tension betwee...
# 4    This show always is excellent, as far as briti...
# Name: reviewText, dtype: object

# %% [markdown]
# ###### Checking the entire 'reviewText' field of the few records of Reviews Dataframe

# %%
print(df_AzReviews[0]['reviewText'][0])
# Out:
# I had big expectations because I love English TV, in particular Investigative and detective stuff but this guy is really boring. It didn't appeal to me at all.

# %%
print(df_AzReviews[1]['reviewText'][1])
# Out:
# Oh, how my little grandson loves this app. He's always asking for "Monkey." Grandma has tired of it long before he has. Finding the items on each page that he can touch and activate is endlessly entertaining for him, at least for now. Well worth the $.99.

# %% [markdown]
# ###### Checking the length (number of characters) in entire 'reviewText' field of the few records of Reviews Dataframe

# %%
print(len(df_AzReviews[0]['reviewText'][0]))
# Out:
# 159

# %%
print(len(df_AzReviews[1]['reviewText'][1]))
# Out:
# 255

# %% [markdown]
# ###### Checking 'Overall' Score (1-5) in the few records of Reviews Dataframe

# %%
print(df_AzReviews[0]['overall'][0])
# Out:
# 2.0

# %%
print(df_AzReviews[1]['overall'][1])
# Out:
# 5.0

# %% [markdown]
# ###### Working with the first few (Head) records of the Reviews and Ratings for testing purposes and creating smaller dataframes

# %%
df_IV5_head = df_AzReviews[0].head()
df_AA5_head = df_AzReviews[1].head()

# %%
df_RT_IV5_head = df_AzRatings[0].head()
df_RT_AA5_head = df_AzRatings[1].head()

# %% [markdown]
# ###### Verifying Head data for Reviews and Ratings

# %%
df_AA5_head
# Out:
#    overall  unixReviewTime   reviewTime  \
# 0      3.0      1383350400   11 2, 2013
# 1      5.0      1323043200   12 5, 2011
# 2      5.0      1337558400  05 21, 2012
# 3      5.0      1354752000   12 6, 2012
# 4      5.0      1391212800   02 1, 2014
#
#                                              summary      reviewerID helpful  \
# 0                                        Really cute  A1N4O8VOJZTDVB  [1, 1]
# 1                                2-year-old loves it  A2HQWU6HUKIEC7  [0, 0]
# 2                                           Fun game  A1SXASF6GYG96I  [0, 0]
# 3                               We love our Monkeys!  A2B54P9ZDYH167  [3, 4]
# 4  This is my granddaughters favorite app on my K...   AFOFZDTX5UC6D  [1, 1]
#
#          asin                                         reviewText  \
# 0  B004A9SDD8  Loves the song, so he really couldn't wait to ...
# 1  B004A9SDD8  Oh, how my little grandson loves this app. He'...
# 2  B004A9SDD8  I found this at a perfect time since my daught...
# 3  B004A9SDD8  My 1 year old goes back to this game over and ...
# 4  B004A9SDD8  There are three different versions of the song...
#
#                     reviewerName   ProductType
# 0                 Annette Yancey  Android Apps
# 1        Audiobook lover "Kathy"  Android Apps
# 2                  Barbara Gibbs  Android Apps
# 3  Brooke Greenstreet "Babylove"  Android Apps
# 4                     C. Galindo  Android Apps

# %%
df_RT_AA5_head
# Out:
#        reviewerID        asin  overall  unixReviewTime   ProductType
# 0  A1ZUSQ3TC3EC4C  B004A9SDD8      5.0      1321574400  Android Apps
# 1   AC05OAXD72X1V  B004A9SDD8      4.0      1367366400  Android Apps
# 2  A2RVMFOKBVM21I  B004A9SDD8      5.0      1350172800  Android Apps
# 3  A3NBSRGUWQGCMZ  B004A9SDD8      1.0      1300838400  Android Apps
# 4  A2KTVCVZJ8GPD2  B004A9SDD8      5.0      1393545600  Android Apps

# %% [markdown]
# ###### Getting metadata of the Ratings Dataframe

# %%
df_RT_AA5_head.shape
# Out:
# (5, 5)

# %%
df_RT_AA5_head.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 5 columns):
# reviewerID        5 non-null object
# asin              5 non-null object
# overall           5 non-null float64
# unixReviewTime    5 non-null int64
# ProductType       5 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 240.0+ bytes

# %%
df_RT_AA5_head.describe()
# Out:
#         overall  unixReviewTime
# count  5.000000    5.000000e+00
# mean   4.000000    1.346700e+09
# std    1.732051    3.663418e+07
# min    1.000000    1.300838e+09
# 25%    4.000000    1.321574e+09
# 50%    5.000000    1.350173e+09
# 75%    5.000000    1.367366e+09
# max    5.000000    1.393546e+09

# %%
df_RT_AA5_head.index
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
df_RT_AA5_head.columns[0]
# Out:
# 'reviewerID'

# %%
df_RT_AA5_head.set_index(df_RT_AA5_head.columns[0],inplace=True)

df_RT_AA5_head.index
# Out:
# Index(['A1ZUSQ3TC3EC4C', 'AC05OAXD72X1V', 'A2RVMFOKBVM21I', 'A3NBSRGUWQGCMZ',
#        'A2KTVCVZJ8GPD2'],
#       dtype='object', name='reviewerID')

# %%
df_RT_AA5_head
# Out:
#                       asin  overall  unixReviewTime   ProductType
# reviewerID
# A1ZUSQ3TC3EC4C  B004A9SDD8      5.0      1321574400  Android Apps
# AC05OAXD72X1V   B004A9SDD8      4.0      1367366400  Android Apps
# A2RVMFOKBVM21I  B004A9SDD8      5.0      1350172800  Android Apps
# A3NBSRGUWQGCMZ  B004A9SDD8      1.0      1300838400  Android Apps
# A2KTVCVZJ8GPD2  B004A9SDD8      5.0      1393545600  Android Apps

# %% [markdown]
# ###### Getting metadata of the Reviews Dataframe

# %%
df_RT_AA5_head.shape
# Out:
# (5, 4)

# %%
df_AA5_head.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 10 columns):
# overall           5 non-null float64
# unixReviewTime    5 non-null int64
# reviewTime        5 non-null object
# summary           5 non-null object
# reviewerID        5 non-null object
# helpful           5 non-null object
# asin              5 non-null object
# reviewText        5 non-null object
# reviewerName      5 non-null object
# ProductType       5 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 440.0+ bytes

# %%
df_AA5_head.describe()
# Out:
#         overall  unixReviewTime
# count  5.000000    5.000000e+00
# mean   4.600000    1.357983e+09
# std    0.894427    2.913811e+07
# min    3.000000    1.323043e+09
# 25%    5.000000    1.337558e+09
# 50%    5.000000    1.354752e+09
# 75%    5.000000    1.383350e+09
# max    5.000000    1.391213e+09

# %%
print(df_AA5_head.index)
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %% [markdown]
# ###### Setting 'reviewerID' as index of DF

# %%
df_AA5_head.columns[8]
# Out:
# 'reviewerName'

# %%
df_AA5_head.set_index(df_AA5_head['reviewerID'],inplace=True)

print(df_AA5_head.index)
# Out:
# Index(['A1N4O8VOJZTDVB', 'A2HQWU6HUKIEC7', 'A1SXASF6GYG96I', 'A2B54P9ZDYH167',
#        'AFOFZDTX5UC6D'],
#       dtype='object', name='reviewerID')

# %%
df_AA5_head
# Out:
#                 overall  unixReviewTime   reviewTime  \
# reviewerID
# A1N4O8VOJZTDVB      3.0      1383350400   11 2, 2013
# A2HQWU6HUKIEC7      5.0      1323043200   12 5, 2011
# A1SXASF6GYG96I      5.0      1337558400  05 21, 2012
# A2B54P9ZDYH167      5.0      1354752000   12 6, 2012
# AFOFZDTX5UC6D       5.0      1391212800   02 1, 2014
#
#                                                           summary  \
# reviewerID
# A1N4O8VOJZTDVB                                        Really cute
# A2HQWU6HUKIEC7                                2-year-old loves it
# A1SXASF6GYG96I                                           Fun game
# A2B54P9ZDYH167                               We love our Monkeys!
# AFOFZDTX5UC6D   This is my granddaughters favorite app on my K...
#
#                     reviewerID helpful        asin  \
# reviewerID
# A1N4O8VOJZTDVB  A1N4O8VOJZTDVB  [1, 1]  B004A9SDD8
# A2HQWU6HUKIEC7  A2HQWU6HUKIEC7  [0, 0]  B004A9SDD8
# A1SXASF6GYG96I  A1SXASF6GYG96I  [0, 0]  B004A9SDD8
# A2B54P9ZDYH167  A2B54P9ZDYH167  [3, 4]  B004A9SDD8
# AFOFZDTX5UC6D    AFOFZDTX5UC6D  [1, 1]  B004A9SDD8
#
#                                                        reviewText  \
# reviewerID
# A1N4O8VOJZTDVB  Loves the song, so he really couldn't wait to ...
# A2HQWU6HUKIEC7  Oh, how my little grandson loves this app. He'...
# A1SXASF6GYG96I  I found this at a perfect time since my daught...
# A2B54P9ZDYH167  My 1 year old goes back to this game over and ...
# AFOFZDTX5UC6D   There are three different versions of the song...
#
#                                  reviewerName   ProductType
# reviewerID
# A1N4O8VOJZTDVB                 Annette Yancey  Android Apps
# A2HQWU6HUKIEC7        Audiobook lover "Kathy"  Android Apps
# A1SXASF6GYG96I                  Barbara Gibbs  Android Apps
# A2B54P9ZDYH167  Brooke Greenstreet "Babylove"  Android Apps
# AFOFZDTX5UC6D                      C. Galindo  Android Apps

# %% [markdown]
# ###### Adding CharCount column -gives char count of ReviewText

# %%
def calculate_charcount(row):
    return len(row['reviewText'])

# %% [markdown]
# ######

# %%
sus = (df_AA5_head['reviewText'].notnull())
suspect = pd.DataFrame()
suspect = df_AA5_head[sus]
suspect
# Out:
#                 overall  unixReviewTime   reviewTime  \
# reviewerID
# A1N4O8VOJZTDVB      3.0      1383350400   11 2, 2013
# A2HQWU6HUKIEC7      5.0      1323043200   12 5, 2011
# A1SXASF6GYG96I      5.0      1337558400  05 21, 2012
# A2B54P9ZDYH167      5.0      1354752000   12 6, 2012
# AFOFZDTX5UC6D       5.0      1391212800   02 1, 2014
#
#                                                           summary  \
# reviewerID
# A1N4O8VOJZTDVB                                        Really cute
# A2HQWU6HUKIEC7                                2-year-old loves it
# A1SXASF6GYG96I                                           Fun game
# A2B54P9ZDYH167                               We love our Monkeys!
# AFOFZDTX5UC6D   This is my granddaughters favorite app on my K...
#
#                     reviewerID helpful        asin  \
# reviewerID
# A1N4O8VOJZTDVB  A1N4O8VOJZTDVB  [1, 1]  B004A9SDD8
# A2HQWU6HUKIEC7  A2HQWU6HUKIEC7  [0, 0]  B004A9SDD8
# A1SXASF6GYG96I  A1SXASF6GYG96I  [0, 0]  B004A9SDD8
# A2B54P9ZDYH167  A2B54P9ZDYH167  [3, 4]  B004A9SDD8
# AFOFZDTX5UC6D    AFOFZDTX5UC6D  [1, 1]  B004A9SDD8
#
#                                                        reviewText  \
# reviewerID
# A1N4O8VOJZTDVB  Loves the song, so he really couldn't wait to ...
# A2HQWU6HUKIEC7  Oh, how my little grandson loves this app. He'...
# A1SXASF6GYG96I  I found this at a perfect time since my daught...
# A2B54P9ZDYH167  My 1 year old goes back to this game over and ...
# AFOFZDTX5UC6D   There are three different versions of the song...
#
#                                  reviewerName   ProductType
# reviewerID
# A1N4O8VOJZTDVB                 Annette Yancey  Android Apps
# A2HQWU6HUKIEC7        Audiobook lover "Kathy"  Android Apps
# A1SXASF6GYG96I                  Barbara Gibbs  Android Apps
# A2B54P9ZDYH167  Brooke Greenstreet "Babylove"  Android Apps
# AFOFZDTX5UC6D                      C. Galindo  Android Apps

# %%
df_AA5_head['charcount_reviewtext'] = suspect.apply(calculate_charcount,axis=1)
df_AA5_head
# Out:
# C:\Program Files\Anaconda33\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                 overall  unixReviewTime   reviewTime  \
# reviewerID
# A1N4O8VOJZTDVB      3.0      1383350400   11 2, 2013
# A2HQWU6HUKIEC7      5.0      1323043200   12 5, 2011
# A1SXASF6GYG96I      5.0      1337558400  05 21, 2012
# A2B54P9ZDYH167      5.0      1354752000   12 6, 2012
# AFOFZDTX5UC6D       5.0      1391212800   02 1, 2014
#
#                                                           summary  \
# reviewerID
# A1N4O8VOJZTDVB                                        Really cute
# A2HQWU6HUKIEC7                                2-year-old loves it
# A1SXASF6GYG96I                                           Fun game
# A2B54P9ZDYH167                               We love our Monkeys!
# AFOFZDTX5UC6D   This is my granddaughters favorite app on my K...
#
#                     reviewerID helpful        asin  \
# reviewerID
# A1N4O8VOJZTDVB  A1N4O8VOJZTDVB  [1, 1]  B004A9SDD8
# A2HQWU6HUKIEC7  A2HQWU6HUKIEC7  [0, 0]  B004A9SDD8
# A1SXASF6GYG96I  A1SXASF6GYG96I  [0, 0]  B004A9SDD8
# A2B54P9ZDYH167  A2B54P9ZDYH167  [3, 4]  B004A9SDD8
# AFOFZDTX5UC6D    AFOFZDTX5UC6D  [1, 1]  B004A9SDD8
#
#                                                        reviewText  \
# reviewerID
# A1N4O8VOJZTDVB  Loves the song, so he really couldn't wait to ...
# A2HQWU6HUKIEC7  Oh, how my little grandson loves this app. He'...
# A1SXASF6GYG96I  I found this at a perfect time since my daught...
# A2B54P9ZDYH167  My 1 year old goes back to this game over and ...
# AFOFZDTX5UC6D   There are three different versions of the song...
#
#                                  reviewerName   ProductType  \
# reviewerID
# A1N4O8VOJZTDVB                 Annette Yancey  Android Apps
# A2HQWU6HUKIEC7        Audiobook lover "Kathy"  Android Apps
# A1SXASF6GYG96I                  Barbara Gibbs  Android Apps
# A2B54P9ZDYH167  Brooke Greenstreet "Babylove"  Android Apps
# AFOFZDTX5UC6D                      C. Galindo  Android Apps
#
#                 charcount_reviewtext
# reviewerID
# A1N4O8VOJZTDVB                   206
# A2HQWU6HUKIEC7                   255
# A1SXASF6GYG96I                   288
# A2B54P9ZDYH167                   186
# AFOFZDTX5UC6D                    746

# %% [markdown]
# ###### Checking if helpful denominator is not a zero and not Nan

# %%
sus1 = (df_AA5_head['helpful'].str[1] != 0.0) & (df_AA5_head['helpful'].dropna()) 

suspect1 = df_AA5_head.loc[sus1]

# %%
suspect1
# Out:
#                 overall  unixReviewTime  reviewTime  \
# reviewerID
# A1N4O8VOJZTDVB      3.0      1383350400  11 2, 2013
# A2B54P9ZDYH167      5.0      1354752000  12 6, 2012
# AFOFZDTX5UC6D       5.0      1391212800  02 1, 2014
#
#                                                           summary  \
# reviewerID
# A1N4O8VOJZTDVB                                        Really cute
# A2B54P9ZDYH167                               We love our Monkeys!
# AFOFZDTX5UC6D   This is my granddaughters favorite app on my K...
#
#                     reviewerID helpful        asin  \
# reviewerID
# A1N4O8VOJZTDVB  A1N4O8VOJZTDVB  [1, 1]  B004A9SDD8
# A2B54P9ZDYH167  A2B54P9ZDYH167  [3, 4]  B004A9SDD8
# AFOFZDTX5UC6D    AFOFZDTX5UC6D  [1, 1]  B004A9SDD8
#
#                                                        reviewText  \
# reviewerID
# A1N4O8VOJZTDVB  Loves the song, so he really couldn't wait to ...
# A2B54P9ZDYH167  My 1 year old goes back to this game over and ...
# AFOFZDTX5UC6D   There are three different versions of the song...
#
#                                  reviewerName   ProductType  \
# reviewerID
# A1N4O8VOJZTDVB                 Annette Yancey  Android Apps
# A2B54P9ZDYH167  Brooke Greenstreet "Babylove"  Android Apps
# AFOFZDTX5UC6D                      C. Galindo  Android Apps
#
#                 charcount_reviewtext
# reviewerID
# A1N4O8VOJZTDVB                   206
# A2B54P9ZDYH167                   186
# AFOFZDTX5UC6D                    746

# %%
suspect1['helpful']
# Out:
# reviewerID
# A1N4O8VOJZTDVB    [1, 1]
# A2B54P9ZDYH167    [3, 4]
# AFOFZDTX5UC6D     [1, 1]
# Name: helpful, dtype: object

# %% [markdown]
# ###### Helpful Numerator

# %%
df_AA5_head['helpful'].str[0]
# Out:
# reviewerID
# A1N4O8VOJZTDVB    1
# A2HQWU6HUKIEC7    0
# A1SXASF6GYG96I    0
# A2B54P9ZDYH167    3
# AFOFZDTX5UC6D     1
# Name: helpful, dtype: int64

# %% [markdown]
# ###### Helpful Denominator

# %%
df_AA5_head['helpful'].str[1]
# Out:
# reviewerID
# A1N4O8VOJZTDVB    1
# A2HQWU6HUKIEC7    0
# A1SXASF6GYG96I    0
# A2B54P9ZDYH167    4
# AFOFZDTX5UC6D     1
# Name: helpful, dtype: int64

# %%
sus2 = (df_AA5_head['helpful'].isnull()) 
sus2
# Out:
# reviewerID
# A1N4O8VOJZTDVB    False
# A2HQWU6HUKIEC7    False
# A1SXASF6GYG96I    False
# A2B54P9ZDYH167    False
# AFOFZDTX5UC6D     False
# Name: helpful, dtype: bool

# %% [markdown]
# ###### Adding  Helpful Percentage, Helpful Numerator & Helpful Denominator columns

# %%
df_AA5_head['helpfulpercentage'] = (np.divide(suspect1['helpful'].str[0],suspect1['helpful'].str[1])* 100).astype(np.int64)
df_AA5_head['helpful_numerator'] = suspect1['helpful'].str[0].astype(np.int64)
df_AA5_head['helpful_denominator'] = suspect1['helpful'].str[1].astype(np.int64)
# Out:
# C:\Program Files\Anaconda33\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Program Files\Anaconda33\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Program Files\Anaconda33\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
df_AA5_head
# Out:
#                 overall  unixReviewTime   reviewTime  \
# reviewerID
# A1N4O8VOJZTDVB      3.0      1383350400   11 2, 2013
# A2HQWU6HUKIEC7      5.0      1323043200   12 5, 2011
# A1SXASF6GYG96I      5.0      1337558400  05 21, 2012
# A2B54P9ZDYH167      5.0      1354752000   12 6, 2012
# AFOFZDTX5UC6D       5.0      1391212800   02 1, 2014
#
#                                                           summary  \
# reviewerID
# A1N4O8VOJZTDVB                                        Really cute
# A2HQWU6HUKIEC7                                2-year-old loves it
# A1SXASF6GYG96I                                           Fun game
# A2B54P9ZDYH167                               We love our Monkeys!
# AFOFZDTX5UC6D   This is my granddaughters favorite app on my K...
#
#                     reviewerID helpful        asin  \
# reviewerID
# A1N4O8VOJZTDVB  A1N4O8VOJZTDVB  [1, 1]  B004A9SDD8
# A2HQWU6HUKIEC7  A2HQWU6HUKIEC7  [0, 0]  B004A9SDD8
# A1SXASF6GYG96I  A1SXASF6GYG96I  [0, 0]  B004A9SDD8
# A2B54P9ZDYH167  A2B54P9ZDYH167  [3, 4]  B004A9SDD8
#                 charcount_reviewtext  helpfulpercentage  helpful_numerator  \
# reviewerID
# A1N4O8VOJZTDVB                   206              100.0                1.0
# A2HQWU6HUKIEC7                   255                NaN                NaN
# A1SXASF6GYG96I                   288                NaN                NaN
# A2B54P9ZDYH167                   186               75.0                3.0
# AFOFZDTX5UC6D                    746              100.0                1.0
#
#                 helpful_denominator  wordcount_reviewtext
# reviewerID
# A1N4O8VOJZTDVB                  1.0                    41
# A2HQWU6HUKIEC7                  NaN                    47
# A1SXASF6GYG96I                  NaN                    52
# A2B54P9ZDYH167                  4.0                    40
# AFOFZDTX5UC6D                   1.0                   134

# %% [markdown]
# ###### Splitting the unixReviewTime field

# %%
import calendar
date = datetime.datetime.utcfromtimestamp(1202256000)
print(date)
print(date.year)
print(date.month)
print(date.day)
print(calendar.day_name[date.weekday()])
# Out:
# 2008-02-06 00:00:00
# 2008
# 2
# 6
# Wednesday

# %%
def GetReview_year(row):
    return datetime.datetime.utcfromtimestamp(row['unixReviewTime']).year
                                               
df_AA5_head['ReviewYear'] = df_AA5_head.apply(GetReview_year,axis=1)
# Out:
# C:\Program Files\Anaconda33\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def GetReview_month(row):
    return datetime.datetime.utcfromtimestamp(row['unixReviewTime']).month
                                               
df_AA5_head['ReviewMonth'] = df_AA5_head.apply(GetReview_month,axis=1)
# Out:
# C:\Program Files\Anaconda33\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def GetReview_day(row):
    return datetime.datetime.utcfromtimestamp(row['unixReviewTime']).day
                                               
df_AA5_head['ReviewDay'] = df_AA5_head.apply(GetReview_day,axis=1)
# Out:
# C:\Program Files\Anaconda33\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def GetReview_dayofweek(row):
    return calendar.day_name[datetime.datetime.utcfromtimestamp(row['unixReviewTime']).weekday()]
                                               
df_AA5_head['ReviewDayofWeek'] = df_AA5_head.apply(GetReview_dayofweek,axis=1)
# Out:
# C:\Program Files\Anaconda33\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_AA5_head
# Out:
#                 overall  unixReviewTime   reviewTime  \
# reviewerID
# A1N4O8VOJZTDVB      3.0      1383350400   11 2, 2013
# A2HQWU6HUKIEC7      5.0      1323043200   12 5, 2011
# A1SXASF6GYG96I      5.0      1337558400  05 21, 2012
# A2B54P9ZDYH167      5.0      1354752000   12 6, 2012
# AFOFZDTX5UC6D       5.0      1391212800   02 1, 2014
#
#                                                           summary  \
# reviewerID
# A1N4O8VOJZTDVB                                        Really cute
# A2HQWU6HUKIEC7                                2-year-old loves it
# A1SXASF6GYG96I                                           Fun game
# A2B54P9ZDYH167                               We love our Monkeys!
# AFOFZDTX5UC6D   This is my granddaughters favorite app on my K...
#
#                     reviewerID helpful        asin  \
# reviewerID
# A1N4O8VOJZTDVB  A1N4O8VOJZTDVB  [1, 1]  B004A9SDD8
# A2HQWU6HUKIEC7  A2HQWU6HUKIEC7  [0, 0]  B004A9SDD8
# A1SXASF6GYG96I  A1SXASF6GYG96I  [0, 0]  B004A9SDD8
# A2B54P9ZDYH167  A2B54P9ZDYH167  [3, 4]  B004A9SDD8
# AFOFZDTX5UC6D    AFOFZDTX5UC6D  [1, 1]  B004A9SDD8
#
#                                                        reviewText  \
# reviewerID
# A1N4O8VOJZTDVB  Loves the song, so he really couldn't wait to ...
# A2HQWU6HUKIEC7  Oh, how my little grandson loves this app. He'...
# A1SXASF6GYG96I  I found this at a perfect time since my daught...
# A2B54P9ZDYH167  My 1 year old goes back to this game over and ...
# AFOFZDTX5UC6D   There are three different versions of the song...
#
#                                  reviewerName   ProductType  \
# reviewerID
# A1N4O8VOJZTDVB                 Annette Yancey  Android Apps
# A2HQWU6HUKIEC7        Audiobook lover "Kathy"  Android Apps
# A1SXASF6GYG96I                  Barbara Gibbs  Android Apps
# A2B54P9ZDYH167  Brooke Greenstreet "Babylove"  Android Apps
# AFOFZDTX5UC6D                      C. Galindo  Android Apps
#
#                 charcount_reviewtext  helpfulpercentage  helpful_numerator  \
# reviewerID
# A1N4O8VOJZTDVB                   206              100.0                1.0
# A2HQWU6HUKIEC7                   255                NaN                NaN
# A1SXASF6GYG96I                   288                NaN                NaN
# A2B54P9ZDYH167                   186               75.0                3.0
# AFOFZDTX5UC6D                    746              100.0                1.0
#
#                 helpful_denominator  wordcount_reviewtext  ReviewYear  \
# reviewerID
# A1N4O8VOJZTDVB                  1.0                    41        2013
# A2HQWU6HUKIEC7                  NaN                    47        2011
# A1SXASF6GYG96I                  NaN                    52        2012
# A2B54P9ZDYH167                  4.0                    40        2012
# AFOFZDTX5UC6D                   1.0                   134        2014
#
#                 ReviewMonth  ReviewDay ReviewDayofWeek
# reviewerID
# A1N4O8VOJZTDVB           11          2        Saturday
# A2HQWU6HUKIEC7           12          5          Monday
# A1SXASF6GYG96I            5         21          Monday
# A2B54P9ZDYH167           12          6        Thursday
# AFOFZDTX5UC6D             2          1        Saturday

# %% [markdown]
# ###### Finding Seasons of the Year in reviewTime data per def below
# Spring runs from March 1 to May 31;
# Summer runs from June 1 to August 31;
# Fall (autumn) runs from September 1 to November 30; and
# Winter runs from December 1 to February 28 (February 29 in a leap year).

# %% [markdown]
# # End of Data Analysis Section on Smaller DataSet

# %% [markdown]
# # Start of Working on Entire Dataset for adding Data Features/Columns and cleanup Section

# %% [markdown]
# ###### Setting the index for both dataFrame Lists i.e. Reviews and Ratings as 'reviewerID'

# %%
for i in range(24):
    df_AzReviews[i].set_index(df_AzReviews[i]['reviewerID'],inplace=True)
    print(df_AzReviews[i].index)
# Out:
# Index(['A11N155CW1UV02', 'A3BC8O2KCL29V2', 'A60D5HQFOTSOM', 'A1RJPIGRSNX4PW',
#        'A16XRPF40679KG', 'A1POFVVXUZR3IQ', 'A1PG2VV4W1WRPL', 'ATASGS8HZHGIB',
#        'A3RXD7Z44T9DHW', 'AUX8EUBNTHIIU',
#        ...
#        'AW3VZ5O895LRK', 'A3DN9249F3X716', 'ACBMCM7S32FZX', 'A2HVL790PBWYTU',
#        'A2EKSOLTKBGWTK', 'A1ELO9LMSE1CQ7', 'AGOEKVIJV9UX6', 'A3I291BE0RNZCU',
#        'A1MNITZRYU71IO', 'A1XMHK9HN5MW2H'],
#       dtype='object', name='reviewerID', length=36797)
# Index(['A1N4O8VOJZTDVB', 'A2HQWU6HUKIEC7', 'A1SXASF6GYG96I', 'A2B54P9ZDYH167',
#        'AFOFZDTX5UC6D', 'A331GYAT4ESYI3', 'A2YEHF8T823TDC', 'A3699WHISXX94Z',
#        'A2BXV49EIES2TB', 'A37HM5TMCMHJES',
#        ...
#        'A1WNAM9WK4JPI1', 'A6JZLY7ZPNTFZ', 'A329Z71KVWP44F', 'AVTWEYS77ITQ5',
#        'A2LAC8Z59WDLP2', 'AZJ11YS0E52AI', 'A2550XGZEFDH2Y', 'A1KNDB16TG5QXD',
#        'A1IHFHA5LI9SGI', 'A3GVFRVK9RYGTV'],
#       dtype='object', name='reviewerID', length=694739)
# Index(['A3F73SC1LY51OO', 'A20S66SKYXULG2', 'A2I8LFSN2IS5EO', 'A3GT2EWQSO45ZG',
#        'A3ESWJPAVRPWB4', 'A1ORODEBRN64C', 'A2R49ZN3G6FTCQ', 'A1Q65KYDKXIX8E',
#        'A3BI8BKIHESDNQ', 'A1R089P5AS26UE',
#        ...
#        'A1RH7WA3YFDQ5H', 'A1PMV0WV45OPEE', 'ACHBPQUWQZMSL', 'A1TEBSNK5A9XX9',
#        'A212UJA6XIOTUT', 'A1KB43BI085A48', 'A3HIUWKL4D853W', 'A1S95WASXJ02VX',
#        'A2IID0Z6EHF5KP', 'A3HKZTFCPIK2OE'],
#       dtype='object', name='reviewerID', length=20260)
# Index(['A1HK2FQW6KXQB2', 'A19K65VY14D13R', 'A2LL1TGG90977E', 'A5G19RYX8599E',
#        'A2496A4EWMLQ7', 'A3OQEVD4C7G3L3', 'ATZDT4B1U7NL', 'A3NMPMELAZC8ZY',
#        'A1ZSTU6RKY1JCL', 'A1TFH58BMFJCR3',
#        ...
#        'A34T0JYVRU1M2B', 'A1AFNMTDISXUJE', 'A1ZS6UQ9RVUX97', 'A3K43QC9YZKVTH',
#        'A3OKEFOUD89F9P', 'A30J0DKNKCF7SR', 'AG4E44KM93P4L', 'A2UZUH4QHV4HA1',
#        'A2Z26PUQPMT5JV', 'A3CIIOMK18CHXM'],
#       dtype='object', name='reviewerID', length=159427)
# Index(['A1YJEY40YUW4SE', 'A60XNB876KYML', 'A3G6XNM240RMWA', 'A1PQFP6SAJ6D80',
#        'A38FVHZTNQ271F', 'A3BTN14HIZET6Z', 'A1Z59RFKN0M5QL', 'AWUO9P6PL1SY8',
#        'A30IP88QK3YUIO', 'APBQH4BS48CQO',
#        ...
#        'A1Y3FEUELH3FTI', 'A3L85FTL937CEC', 'AHAHJZ0Y7B485', 'A34BZM6S9L7QI4',
#        'A3NHUQ33CFH3VM', 'A2BLFCOPSMBOZ9', 'A1UQBFCERIP7VJ', 'A35Q0RBM3YNQNF',
#        'A3LGT6UZL99IW1', 'A3UJRNI8UR4871'],
#       dtype='object', name='reviewerID', length=197116)
# Index(['A10000012B7CGYKOMPQ4L', 'A2S166WSCFIFP5', 'A1BM81XB4QHOA3',
#        'A1MOSTXNIO5MPJ', 'A2XQ5LZHTD4AFT', 'A3V1MKC2BVWY48', 'A12387207U8U24',
#        'A29TRDMK51GKZR', 'A3FI0744PG1WYG', 'A2LBBQHYLEHM7P',
#        ...
#        'A1MW856C6F1KXO', 'A3PNKLCGVG1P3P', 'A2G3DE7EYTVZG9', 'A76D0PDO97IIJ',
#        'A23VHARP9XPOXI', 'A2Y66HD4J5S7QZ', 'A17YHECC8H9NEY', 'A20KO0BPMNREJL',
#        'A1BQO66R6OLCCW', 'A2NRGE3CSFY2TQ'],
#       dtype='object', name='reviewerID', length=8872495)
# Index(['A3IEV6R2B7VW5Z', 'A2H3ISQ4QB95XN', 'A6GMEO3VRY51S', 'A3E102F6LPUF1J',
#        'A2JP0URFHXP6DO', 'A31GBCW6YPY9OW', 'A3QAV7LALVG1F7', 'A1BFRIT70VHDF8',
#        'AEFGR6NFTNWH0', 'A24GD1AWG77IDJ',
#        ...
#        'A3M90JAMX1EF21', 'A3SNR4JFS5WF4Y', 'A1DSES64WY3DGM', 'A2QNOQE9A736GS',
#        'A1B621EA66Z8KV', 'AMU11SMXH2CB9', 'A32WMA7RM265U9', 'A3UKLX2A9T589C',
#        'ASSFEY7BG5KIO', 'A3EVGPGOFVAP09'],
#       dtype='object', name='reviewerID', length=1094651)
# Index(['A30TL5EWN6DFXT', 'ASY55RVNIL0UD', 'A2TMXE2AFO7ONB', 'AWJ0WZQYMYFQ4',
#        'ATX7CZYFXI1KW', 'APX47D16JOP7H', 'A1JVVYYO7G56DS', 'A6FGO4TBZ3QFZ',
#        'A2JWEDW5FSVB0F', 'A8AJS1DW7L3JJ',
#        ...
#        'AF30DHAVSYNZ0', 'A34KTJ4VWNBOHI', 'A1Q1Z7IR79G52A', 'A388OX0ZF7OT8R',
#        'A2BLFCOPSMBOZ9', 'A1YMNTFLNDYQ1F', 'A15TX8B2L8B20S', 'A3JI7QRZO1QG8X',
#        'A1NHB2VC68YQNM', 'A1AG6U022WHXBF'],
#       dtype='object', name='reviewerID', length=190920)
# Index(['A1KLRMWW2FWPL4', 'A2G5TCU2WDFZ65', 'A1RLQXYNCMWRWN', 'A8U3FAMSJVHS5',
#        'A3GEOILWLK86XM', 'A27UF1MSF3DB2', 'A16GFPNVF4Y816', 'A2M2APVYIB2U6K',
#        'A1NJ71X3YPQNQ9', 'A3EERSWHAI6SO',
#        ...
#        'A2NOW4U7W3F7RI', 'A1W415JP5WEAJK', 'AX05DBU8IRUWY', 'AEL6CQNQXONBX',
#        'ACJT8MUC0LRF0', 'A2DG63DN704LOI', 'A1EVV74UQYVKRY', 'A1UQBFCERIP7VJ',
#        'A22CW0ZHY3NJH8', 'A30VWT3R25QAVD'],
#       dtype='object', name='reviewerID', length=278225)
# Index(['A3EBHHCZO6V2A4', 'AZPWAXJG9OJXV', 'A38IRL0X2T4DPF', 'A22IK3I6U76GX0',
#        'A1AISPOIIHTHXX', 'A2P49WD75WHAG5', 'A3O90G1D7I5EGG', 'A3EJYJC25OJVKK',
#        'A1DA8VOH9NR6C7', 'A33TRNCQK4IUO7',
#        ...
#        'A11BF3WX0WJ24N', 'A24N1BAS3CU27H', 'A2O57LB3BP3WTS', 'A1VL282XIRMEEQ',
#        'A3VXBO4QQX3ZG8', 'A1PQ1PESSO8CMO', 'A120RH58WVY4W6', 'A19VJ2IQLO50G0',
#        'AUDSM2CTLLW1Q', 'A1GN8UJIZLCA59'],
#       dtype='object', name='reviewerID', length=64529)
# Index(['AO94DHGC771SJ', 'AMO214LNFCEI4', 'A3N7T0DY83Y4IG', 'A1H8PY3QHMQQA0',
#        'A24EV6RXELQZ63', 'A2JXAZZI9PHK9Z', 'A2P5U7BDKKT7FW', 'AAZ084UMH8VZ2',
#        'AEZ3CR6BKIROJ', 'A3BY5KCNQZXV5U',
#        ...
#        'A26VF18X91983P', 'A2XRMQA6PJ5ZJ8', 'A3A4ZAIBQWKOZS', 'AOVTLYTHVDNUX',
#        'A1AJVEBU3Y8GB', 'A34BZM6S9L7QI4', 'A1G650TTTHEAL5', 'A25C2M3QF9G7OQ',
#        'A1E1LEVQ9VQNK', 'A2NYK9KWFMJV4Y'],
#       dtype='object', name='reviewerID', length=1664458)
# Index(['A1VEELTKS8NLZB', 'A14R9XMZVJ6INB', 'A27IQHDZFQFNGG', 'A31QY5TASILE89',
#        'A2LWK003FFMCI5', 'A1NZJTY0BAA2SK', 'AA95FYFIP38RM', 'A3FIVHUOGMUMPK',
#        'A27FSPAMTQF1J8', 'A33NXNZ79H5K51',
#        ...
#        'A11T807LX2EF00', 'A3W4D8XOGLWUN5', 'A3H0ZQ74ITU83J', 'A3RJR9UL7HEROC',
#        'A3VYKXHQDICC6', 'A2L6QS8SVHT9RG', 'AFJFXN42RZ3G2', 'ASEBX8TBYWQWA',
#        'ANKQGTXHREOI5', 'A2CF66KIQ3RKX3'],
#       dtype='object', name='reviewerID', length=149761)
# Index(['ALC5GH8CAMAI7', 'AHKSURW85PJUE', 'A38RMU1Y5TDP9', 'A1XZUG7DFXXOS4',
#        'A1MS3M7M7AM13X', 'AXO4PQU0XG3TG', 'A28X0LT2100RL1', 'A1VUSWRVN8SJA8',
#        'A1JQDCX4LDKBZ3', 'A3RNRXOM5J2C93',
#        ...
#        'A7WCB7DDU6J5Z', 'A2AVWHAP4IUN0G', 'AO4D7TQLTI530', 'A2NIGPQX34K47O',
#        'A1K3L3CVDVSKH2', 'A11J1FHCK5U06J', 'AFVKI7BCS3FSX', 'A1Y3FEUELH3FTI',
#        'A11LC938XF35XN', 'A2I8KUDXTC9WYI'],
#       dtype='object', name='reviewerID', length=343304)
# Index(['APYOBQE6M18AA', 'A1JVQTAGHYOL7F', 'A3UPYGJKZ0XTU4', 'A2MHCTX43MIMDZ',
#        'AHAI85T5C2DH3', 'AXA9EVY6IJIZ5', 'A1SW2D234X11MS', 'A1ZH5ULI4SBO48',
#        'A1V13XAWO98C1J', 'A3842PXNQ1QRM9',
#        ...
#        'AAOYA0DKWED4W', 'AWFGKB5SCJAO2', 'A14NHXPYTSZ2HT', 'A7WCB7DDU6J5Z',
#        'A21T5C3KL41REL', 'A11J1FHCK5U06J', 'A537XC69FAD3J', 'AWHZOUIQ0VO7M',
#        'A1KQNP8MOJDJKC', 'A3AHOSISKNBLZ6'],
#       dtype='object', name='reviewerID', length=546729)
# Index(['A1F6404F1VG29J', 'AN0N05A9LIJEQ', 'A795DMNCJILA6', 'A1FV0SX13TWVXQ',
#        'A3SPTOKDG7WBLN', 'A1RK2OCZDSGC6R', 'A2HSAKHC3IBRE6', 'A3DE6XGZ2EPADS',
#        'A1UG4Q4D3OAH3A', 'AQZH7YTWQPOBE',
#        ...
#        'A1MW856C6F1KXO', 'A3PNKLCGVG1P3P', 'A2G3DE7EYTVZG9', 'A76D0PDO97IIJ',
#        'A23VHARP9XPOXI', 'A2Y66HD4J5S7QZ', 'A17YHECC8H9NEY', 'A20KO0BPMNREJL',
#        'A1BQO66R6OLCCW', 'A2NRGE3CSFY2TQ'],
#       dtype='object', name='reviewerID', length=978820)
# Index(['ADZPIG9QOCDG5', 'A35947ZP82G7JH', 'A3UORV8A9D5L2E', 'A1VKW06X1O2X7V',
#        'A3R27T4HADWFFJ', 'A2L0G56BNOTX6S', 'A5NYUBEKXFLX5', 'A2DJ8B8GE4V2VD',
#        'AWF2S3UNW9UA0', 'A3O4UUT83DG3OU',
#        ...
#        'APO10VQE3MAKE', 'A3PPYOJBMFBP6U', 'A3UHLJGZ2E84A5', 'A22OB0DIJ5FO0G',
#        'A2CA2Q6JS6CQAE', 'AV657BUYHHXZ2', 'A17W587EH23J0Q', 'A3DE438TF1A958',
#        'A2RWCXDMANY0LW', 'A3ROPC55BE2OM9'],
#       dtype='object', name='reviewerID', length=1691457)
# Index(['A2IBPI20UZIR0U', 'A14VAT5EAX3D9S', 'A195EZSQDW3E21', 'A2C00NNG1ZQQG2',
#        'A94QU4C90B1AX', 'A2A039TZMZHH9Y', 'A1UPZM995ZAH90', 'AJNFQI3YR6XJ5',
#        'A3M1PLEYNDEYO8', 'AMNTZU1YQN1TH',
#        ...
#        'A3M1PLEYNDEYO8', 'A1SD1C8XK3Z3V1', 'A2VRAT69JDAD3W', 'A306NASGVUDFKF',
#        'A1TSKKBNV38E8Y', 'A14B2YH83ZXMPP', 'A1RPTVW5VEOSI', 'AWCJ12KBO5VII',
#        'A2Z7S8B5U4PAKJ', 'A2WA8TDCTGUADI'],
#       dtype='object', name='reviewerID', length=10234)
# Index(['A32T2H8150OJLU', 'A3MAFS04ZABRGO', 'A1F1A0QQP2XVH5', 'A49R5DBXXQDE5',
#        'A2XRMQA6PJ5ZJ8', 'A2JFOHC9W629IE', 'A38NELQT98S4H8', 'AA8M6331NI1EN',
#        'A25C2M3QF9G7OQ', 'A1RTVWTWZSIC94',
#        ...
#        'A185QFJRTB5W93', 'A3JVN244YWI3F3', 'A2TI5R93FF69UN', 'AYB4ELCS5AM8P',
#        'AZMY6E8B52L2T', 'A1ODOGXEYECQQ8', 'A2XX2A4OJCDNLZ', 'A3LGT6UZL99IW1',
#        'A1XJOSJN6FHFO0', 'AAEVGE52KL0DJ'],
#       dtype='object', name='reviewerID', length=52799)
# Index(['A1JZFGZEZVWQPY', 'A32JCI4AK2JTTG', 'A3N0P5AAMP6XD2', 'A2QK7UNJ857YG',
#        'AS0CYBAN6EM06', 'A2UO040HWOP0C2', 'A1VGXHHR08G044', 'A1U6RLUA8D5DSX',
#        'A2JSYW3B4KPD7I', 'A126CN6N93XLZU',
#        ...
#        'ABDR6IJ93HFIO', 'ACJT8MUC0LRF0', 'A1LACH6MLQWZ', 'A31W55J90T8NFF',
#        'A28EMTHVF120XV', 'AT53ZTTO707MB', 'AYB4ELCS5AM8P', 'AZMY6E8B52L2T',
#        'AEC90GPFKLAAW', 'A3LGT6UZL99IW1'],
#       dtype='object', name='reviewerID', length=13107)
# Index(['A14CK12J7C7JRK', 'A39QHP5WLON5HV', 'A2CR37UY3VR7BN', 'A2A4COGL9VW2HY',
#        'A2UBQA85NIGLHA', 'A2V3UP9NPMHVKJ', 'A2R4JCEFLTFU8F', 'A14B4MJ7KZE63B',
#        'A2JDB26Y78TT8Z', 'A8GY0E0SS8VMD',
#        ...
#        'A3NHUQ33CFH3VM', 'A3VBXQKRM7A4JR', 'A13H5US9Z7L9M7', 'A31RULW0KNYJ5H',
#        'AAA0TUKS5VBSA', 'A136YD08SCJ2LV', 'A2YKWYC3WQJX5J', 'A2K0D19N83G6U2',
#        'A3A4ZAIBQWKOZS', 'A1ITRGMT80D5TK'],
#       dtype='object', name='reviewerID', length=156493)
# Index(['AIXZKN4ACSKI', 'A1L5P841VIO02V', 'AB2W04NI4OEAD', 'A148SVSWKTJKU6',
#        'AAAWJ6LW9WMOO', 'A2XX2A4OJCDNLZ', 'A283UOBQRUNM4Q', 'AWG3H90WVZ0Z1',
#        'A3V52OTJHKIJZX', 'A3SZBE5F3UQ9EC',
#        ...
#        'A1PI8VBCXXSGC7', 'A1UQBFCERIP7VJ', 'A35Q0RBM3YNQNF', 'A2NYK9KWFMJV4Y',
#        'A22CW0ZHY3NJH8', 'A2XX2A4OJCDNLZ', 'A3LGT6UZL99IW1', 'ASKZO80Z1RKTR',
#        'APRNS6DB68LLV', 'A3UJRNI8UR4871'],
#       dtype='object', name='reviewerID', length=294935)
# Index(['A4IL0CLL27Q33', 'A3Q5W5E7TDVLJF', 'A37KNOJXE2FU6', 'A3U4AFML9SZPWK',
#        'A36Y7X194VWVKA', 'A2GD2HORAJHBK5', 'A7KVMEIDJP0JK', 'A3VRFONBPYVIY8',
#        'A3UOK4B9B2PCG9', 'AQ3ARAU1JBTQU',
#        ...
#        'A15TX8B2L8B20S', 'A11LC938XF35XN', 'A2I8KUDXTC9WYI', 'A390XPHE9J7DBO',
#        'AP9USU1C1C21P', 'A1Q1Z7IR79G52A', 'A21T5C3KL41REL', 'A2I8KUDXTC9WYI',
#        'AAOYA0DKWED4W', 'A18JF0T0GOCORW'],
#       dtype='object', name='reviewerID', length=133757)
# Index(['A1VXOAVRGKGEAK', 'A8R62G708TSCM', 'A21KH420DK0ICA', 'AR29QK6HPFYZ4',
#        'ACCH8EOML6FN5', 'A1EDPGHC9EYBUN', 'A181ZNB42LISRZ', 'A1RBEJ5UQ1RWAW',
#        'AFGGC7SIV964O', 'A2XU46XXNV19C8',
#        ...
#        'A2WTZYJFWNRAOI', 'A2JK8WHJP2DO46', 'A2KMMT6KLYAFFF', 'A25AK08Y7U11K8',
#        'A1Z1CXYSRAD4C', 'A18Q24BZK2CB5P', 'A1I8ON1X0B2N2W', 'A3V24H5350ULKI',
#        'A1W2F1WI0QZ4AJ', 'AV6WVMUJVUHNB'],
#       dtype='object', name='reviewerID', length=166759)
# Index(['A2HD75EMZR8QLN', 'A3UR8NLLY1ZHCX', 'A1INA0F5CWW3J4', 'A1DLMTOTHQ4AST',
#        'A361M14PU2GUEG', 'A2UTRVO4FDCBH6', 'AN3YYDZAS3O1Y', 'AQTC623NCESZW',
#        'A1QJJU33VNC4S7', 'A2JLT2WY0F2HVI',
#        ...
#        'A1MHB1HRR6VPEH', 'A2IGEPJJYKMOWK', 'A1M19BGTJ5PI1I', 'A3PG9EEZMT9CJF',
#        'A1V6WWYN2S6V40', 'A1ICREREXO9J81', 'A3VVMIMMTYQV5F', 'A1DD4B97M4DUC5',
#        'A2Q9CNJ4T6ZK99', 'A27CD59R5U58GG'],
#       dtype='object', name='reviewerID', length=228967)

# %%
for i in range(24):
    df_AzRatings[i].set_index(df_AzRatings[i]['reviewerID'],inplace=True)
    print(df_AzRatings[i].index)
# Out:
# Index(['AGZ8SM1BGK3CK', 'A2VHZ21245KBT7', 'ACX8YW2D5EGP6', 'A9RNMO9MUSMTJ',
#        'A3STFVPM8NHJ7B', 'A2582KMXLK2P06', 'A1TZCLCW9QGGBH', 'A2E2I6B878CRMA',
#        'AD5MZA8SOVMPJ', 'A3IE1M3QVUKIJN',
#        ...
#        'A3U3RFL0XE4F7V', 'AOK8AARD069GP', 'A1IWX2XBFTCMSR', 'A37IYQC8EKLDYJ',
#        'AJE4MXRQ5W9JU', 'A9MBSKL8LTFN9', 'A3U3RFL0XE4F7V', 'AEO407GROR6JB',
#        'A2YXWWVABHWIXN', 'ANZJEQZRYUCBC'],
#       dtype='object', name='reviewerID', length=583932)
# Index(['A1ZUSQ3TC3EC4C', 'AC05OAXD72X1V', 'A2RVMFOKBVM21I', 'A3NBSRGUWQGCMZ',
#        'A2KTVCVZJ8GPD2', 'A2I9RREBHMMPCJ', 'A1N4O8VOJZTDVB', 'A2HQWU6HUKIEC7',
#        'A1SXASF6GYG96I', 'A2B54P9ZDYH167',
#        ...
#        'A2CYMBX44ICBMD', 'A15CK6OV006IWW', 'A1GNY9105V63S4', 'A3AY7CSC53ULU6',
#        'A15U4R5HB5QE2M', 'A1WKBCDSH3AORB', 'A1WKBCDSH3AORB', 'AO7VN21R9P2MM',
#        'A3I9KEWNIJKOT0', 'A27OTO46BZUF83'],
#       dtype='object', name='reviewerID', length=2638171)
# Index(['A1QBLUSZW281TA', 'A3B40ZIZJ3HEP7', 'A1DUAXYX5WHSX1', 'A1VS7YWE0NCAS3',
#        'AY04DS9CPM1YH', 'A2HHDDYLFIQWYA', 'A12T7O6K54JTJM', 'A1UXFMMV5CPPJQ',
#        'AR040DQNCVR0H', 'A9XSCMBQVNUPS',
#        ...
#        'A2RYJQPMNVOWK6', 'A1K3BF6U9GO6F8', 'ABI7KXVCTSS8F', 'A3BG7Q6NNZCEGP',
#        'A8BXQ7Z2M01AG', 'A1TCZF6H0ZULVU', 'A1QFCZCVEA4Y2Q', 'A1MUILE70L0N2J',
#        'ATHXXHPG0APQN', 'A38HD4B3ZJ63IW'],
#       dtype='object', name='reviewerID', length=1373767)
# Index(['AX0M1Z6ZWO52J', 'A1KD7N84L7NIUT', 'A29CUDEIF4X1UO', 'A32592TYN6C9EM',
#        'AA9X14MODL8XJ', 'AHAWBFF74JFGM', 'A3N6R7ONCCY2D', 'A1Y9UZAZHG0P5A',
#        'ATTTLHRK3VOOL', 'A3BRNASAP5PDFZ',
#        ...
#        'A1BN3HNG4PZYTM', 'A2B3WBNVQSLM6V', 'A1FSRXEF9D588F', 'A2YDMQCHYJIYPG',
#        'A3O8O1EMXIB3T9', 'A3U7438NXFL16A', 'A1K0FYAEF3H0UP', 'A25DMFZ9UR90S6',
#        'AVH3CQ9L55WW0', 'A10JX4YDI39S17'],
#       dtype='object', name='reviewerID', length=915445)
# Index(['A3JM6GV9MNOF9X', 'A1Z513UWSAAO0F', 'A1WMRR494NWEWV', 'A3IAAVS479H7M7',
#        'AKJHHD5VEH7VG', 'A1BG8QW55XHN6U', 'A22VW0P4VZHDE3', 'A3V3RE4132GKRO',
#        'A327B0I7CYTEJC', 'A1BG8QW55XHN6U',
#        ...
#        'A3EN0JCMEML724', 'A1RYQPQ01T5D5R', 'A3MQDRRGC9070R', 'A2LB743IV4NS2W',
#        'A1YSYUGR6XRMIW', 'A3DEHKPFANB8VA', 'A3DEHKPFANB8VA', 'AG9TJLJUN5OM3',
#        'AYBIB14QOI9PC', 'A1PB6OT0OOPKNQ'],
#       dtype='object', name='reviewerID', length=2023069)
# Index(['A2IIIDRK3PRRZY', 'A1TADCM7YWPQ8M', 'AWGH7V0BDOJKB', 'A3UTQPQPM4TQO0',
#        'A8ZS0I5L5V31B', 'ACNGUPJ3A3TM9', 'A3BED5QFJWK88M', 'A2SUAM1J3GNN3B',
#        'APOZ15IEYQRRR', 'AYEDW3BFK53XK',
#        ...
#        'A2Y66HD4J5S7QZ', 'A2ZKU5ACWAB2R2', 'AFU5KBOMUSF75', 'A17YHECC8H9NEY',
#        'AQSL89CSKJYB1', 'A20KO0BPMNREJL', 'A1BQO66R6OLCCW', 'A1CI87FHKK6HVC',
#        'A8W4BR3HGGS3C', 'A2NRGE3CSFY2TQ'],
#       dtype='object', name='reviewerID', length=22507154)
# Index(['AHG1GTQZUYNJN', 'A2TFO7NREP2B2D', 'A2YAPAG1IPNK7K', 'AEKGGV851HY3K',
#        'A2MRQG8RN5JI7R', 'A12R54MKO17TW0', 'A1C7NPVPFF4OO8', 'A22X72C51HQ7AS',
#        'A1JE8B5PU9ISMC', 'A1WX42M589VAMQ',
#        ...
#        'A3ME85ENCV5HHL', 'A3JAVKH94T5NM1', 'A2PMBMJFGRK38B', 'A208XBJSSYUP29',
#        'A3RKUPYX1RC9WO', 'A122G17YDFX176', 'A26QVK35BBBKU8', 'A1V76VMZ0N3H5W',
#        'A248BRA9BLBUJ2', 'A3VKP3B68JX4SB'],
#       dtype='object', name='reviewerID', length=3749003)
# Index(['A1YX2RBMS1L9L', 'A180NNPPKWCCU0', 'A3HVRXV0LVJN7', 'A292527VPX98P8',
#        'A1BJGDS0L1IO6I', 'ANG01NK4RXCI9', 'AL7D46UHDVZVC', 'A1KO9L34Z7548N',
#        'A30P2CYOUYAJM8', 'A3KN7WFLV7LKBM',
#        ...
#        'A10K98QSJKNXM7', 'A3315VWQGK0DO4', 'A12DT4IRKYMD1Z', 'A1SHKKG5D93TP8',
#        'A140HTQ9B38BL4', 'A13XYYFUXCC1TR', 'A26D35B144FHDK', 'AUKHZBW58JEGE',
#        'AJN5FX35AU4TK', 'A1NR37AER89LHF'],
#       dtype='object', name='reviewerID', length=3447248)
# Index(['A2G0LNLN79Q6HR', 'A2R3K1KX09QBYP', 'A19PBP93OF896', 'A1P0IHU93EF9ZK',
#        'A3Q6CTO56DJ8UZ', 'A1KLRMWW2FWPL4', 'A1GQPAM8Y45QN7', 'A2G5TCU2WDFZ65',
#        'AEAN37KUOYSX4', 'A1MCJONUQ78L9T',
#        ...
#        'A3S50DYBCR1VYY', 'A23GH1QN8WUCBM', 'A18A9VTV5ZBOFR', 'A1XPBXYFUAV022',
#        'A2EZTQIN3V34P9', 'A2WM2M3ORU1W7N', 'A2QCFP9FIIJDLI', 'A5007NDXGUUT1',
#        'A2Y2Z08V4KJ8O2', 'A2NW9ZABCLC1H4'],
#       dtype='object', name='reviewerID', length=5748919)
# Index(['A1WR23ER5HMAA9', 'A2IR4Q0GPAFJKW', 'A2V0KUVAB9HSYO', 'A1J0GL9HCA7ELW',
#        'A3EBHHCZO6V2A4', 'A340XJYJDFSMUG', 'A3Q1J7VFGG80EK', 'A1REP2FMPOXV4A',
#        'A3QEKUPBPQ7A2S', 'A4BHT5EUI0ZJF',
#        ...
#        'A3HJS000P7AC0Q', 'A1BSP3G2B7UNBK', 'A3LV9NGAOMV9NN', 'A1QP5WSKUYZUMG',
#        'A3LWJETAAAD4OU', 'A38NRGVVEF3950', 'A36ZEAXJ5HMQXA', 'A1840L5R4OPDE4',
#        'A1HGHLLGGGAQZX', 'A2SWE776KGEYPI'],
#       dtype='object', name='reviewerID', length=836005)
# Index(['A2CX7LUOHB2NDG', 'A2NWSAGRHCP8N5', 'A2WNBOD3WNDNKT', 'A1GI0U4ZRJA8WN',
#        'A1QGNMC6O1VW39', 'A3J3BRHTDRFJ2G', 'A2TY0BTJOTENPG', 'A34ATBPOK6HCHY',
#        'A89DO69P0XZ27', 'AZYNQZ94U6VDB',
#        ...
#        'A5FUA9HEV2O42', 'A84WRQR47OOKR', 'A180UGKKYCPDH0', 'A2R6Q6KJCYSVH7',
#        'A2IGIIABRZ5LAB', 'A2YZI3C9MOHC0L', 'A322MDK0M89RHN', 'A1MH90R0ADMIK0',
#        'A10M2KEFPEQDHN', 'A2G81TMIOIDEQQ'],
#       dtype='object', name='reviewerID', length=7824481)
# Index(['A31W38VGZAUUM4', 'A3I0AV0UJX5OH0', 'A3QAAOLIXKV383', 'AB1A5EGHHVA9M',
#        'A3DTB6RVENLQ9Q', 'A3LZA698SQPCXE', 'A2XZPK86YY9R6G', 'A2MWO0CISKXJ9',
#        'ACDUAY8AH3T72', 'A11WU9TYDLB1RG',
#        ...
#        'A12XIXE9S64TF7', 'A2DG81T8YR0PTM', 'ACF0NFD95VRUS', 'AMJB5BFAUE081',
#        'A6B61KJ12Z9SV', 'A1DGBQQIBHTLPF', 'A3DYJ90MXMH04P', 'AWQYAJV2QWLWA',
#        'A2AT0AI6QKSY2C', 'A2NSZZ7Y0RAE45'],
#       dtype='object', name='reviewerID', length=1297155)
# Index(['A3FYN0SZYWN74', 'A2J0WRZSAAHUAP', 'A38RKP6G5P8J63', 'ARENM677YXZKX',
#        'AMBJQQSRCAOHS', 'A2KX3GMQY9LS9N', 'A35G5VLYZIDBAU', 'A12V35OD8T4ZVP',
#        'AVFXCA5AW8I7F', 'A2COS3K6OVGHO8',
#        ...
#        'A1VFDX3YSXIWCP', 'A15DIPLUBR29SR', 'A2CFE61XGDKIM5', 'ARQSWNLE6SY0X',
#        'A23F7EJG7QUHHI', 'A3JAH75UZEDDE3', 'A32X30YGYWDTCZ', 'A1252ETWUJRKVC',
#        'A215W0EOUNL81C', 'A2ZFFXGLJUHD76'],
#       dtype='object', name='reviewerID', length=2982325)
# Index(['A28ILV4TOG8BH2', 'A31B4D7URW4DNZ', 'A2HU0RPDRZZOP1', 'A7J0XOW7DYBBD',
#        'A9QY9F2Y7KDFW', 'A2MGJ4CELCSG10', 'A1S0DWONNWB8NH', 'A1FUE4TEATOQVV',
#        'A399RHVLQVXMA1', 'A1S0WZTK4QTY6O',
#        ...
#        'AF30DHAVSYNZ0', 'A34KTJ4VWNBOHI', 'A4XPE5UGK51IA', 'A2G7RZI15ZPCTH',
#        'A2V247ZQT9OJIT', 'AF30DHAVSYNZ0', 'A34KTJ4VWNBOHI', 'A4XPE5UGK51IA',
#        'A2LUDC2DWHMRDA', 'ADL558O3IM9DY'],
#       dtype='object', name='reviewerID', length=4253925)
# Index(['A1K7VSUDCVAPW8', 'A35J5XRE5ZT6H2', 'A3DGZNFSMNWSX5', 'A2CVDQ6H36L4VL',
#        'A3U0EV8PXX6G2O', 'A18KZLAOO17CH7', 'A1RYEDOAVTVC97', 'AW4GYRDGPXSHC',
#        'A3RM23R5S3OBO5', 'A5T79U2IMPYTY',
#        ...
#        'A2Y66HD4J5S7QZ', 'A2ZKU5ACWAB2R2', 'AFU5KBOMUSF75', 'A17YHECC8H9NEY',
#        'AQSL89CSKJYB1', 'A20KO0BPMNREJL', 'A1BQO66R6OLCCW', 'A1CI87FHKK6HVC',
#        'A8W4BR3HGGS3C', 'A2NRGE3CSFY2TQ'],
#       dtype='object', name='reviewerID', length=3205466)
# Index(['A3R5OBKS7OM2IR', 'AH3QC2PC1VTGP', 'A3LKP6WPMP9UKX', 'AVIY68KEPQ5ZD',
#        'A1CV1WROP5KTTW', 'AP57WZ2X4G0AA', 'A3NMBJ2LCRCATT', 'A5Y15SAOMX6XA',
#        'A3P671HJ32TCSF', 'A3VCKTRD24BG7K',
#        ...
#        'A17W587EH23J0Q', 'A3E4Q2YOYCKXON', 'A1U1UNV1RLCKRL', 'A14THKG1X8861X',
#        'A3DE438TF1A958', 'AHCV1RTGY3PJ8', 'A2RWCXDMANY0LW', 'A3V9PIFRME2XCW',
#        'A3ROPC55BE2OM9', 'A2ARBNMH5Q5YM1'],
#       dtype='object', name='reviewerID', length=4607046)
# Index(['A3TS466QBAWB9D', 'A3BUDYITWUSIS7', 'A19K10Z0D2NTZK', 'A14X336IB4JD89',
#        'A2HR0IL3TC4CKL', 'A2DHYD72O52WS5', 'A1MUVHT8BONL5K', 'A15GZQZWKG6KZM',
#        'A16WE7UU0QD33D', 'AXMWZYP2IROMP',
#        ...
#        'A1TRI02HX2JACU', 'A1EITL4Y22NWC0', 'A3DZ8K2Q63HD3M', 'A2B36P2QL36J7U',
#        'A2S8D30M5198PF', 'A2XEVARMJP81E', 'A3PAQGM6P87MXO', 'A2KZX7A4XZ4T2W',
#        'AIDHT6KXOL64T', 'A161I1MHX2G2BR'],
#       dtype='object', name='reviewerID', length=500175)
# Index(['A3BBNK2R5TUYGV', 'A5J78T14FJ5DU', 'A2P462UH5L6T57', 'A2E0X1MWNRTQF4',
#        'AAYGDWCI3LDQP', 'AI7SARYVM8FGA', 'A1BUVOGGFTGMBN', 'A35UM9B38X7AYS',
#        'AM2U8KJROWYKR', 'A1V1VJ3W1SYJU0',
#        ...
#        'A1SVC9PU6HOB1Y', 'AJLLEY3AE4XXO', 'A2DPMFL7HUI91N', 'A3GAVF0BFS1SD8',
#        'A1DDIW7RL1V9SK', 'A23UIUEO9PVK1G', 'A3W0IG7LIY99CK', 'AX0OWSOOJA1ZJ',
#        'A17R4GQHT3RW2R', 'A12TWUP92WJJHB'],
#       dtype='object', name='reviewerID', length=1243185)
# Index(['A20DWVV8HML3AW', 'A3RVP3YBYYOPRH', 'A28XY55TP3Q90O', 'A3VZW1BGUQO0V3',
#        'A2R9T5D7UVQZB0', 'A2MH49GAEWEI95', 'AR5DPX4ZU3D4Z', 'A3OGMCRM3NL8OM',
#        'A7E1GKNNT96QQ', 'A1NCJWD2ZQBXW2',
#        ...
#        'A2G7RZI15ZPCTH', 'A2V247ZQT9OJIT', 'AF30DHAVSYNZ0', 'A34KTJ4VWNBOHI',
#        'A4XPE5UGK51IA', 'A2G7RZI15ZPCTH', 'A2V247ZQT9OJIT', 'AF30DHAVSYNZ0',
#        'A34KTJ4VWNBOHI', 'A4XPE5UGK51IA'],
#       dtype='object', name='reviewerID', length=993489)
# Index(['A363P047LR5XI6', 'ABZ8CQXD42H4', 'A3J8QW1MV1OP01', 'A3ISA8Z0NB0ILH',
#        'A2A8F5QRQOAWVS', 'A3FH308L8K5Q9M', 'A2BD1HQS031I6U', 'AK5D5XJ7OHNFG',
#        'A2H6BM7IZI4U6K', 'A2XP5QT0IFQWI7',
#        ...
#        'A34L8JDPZ30TPT', 'A2AE0A7D4B86G', 'AYC3200BA4E38', 'A336LLU4DZP5M2',
#        'A3I2JI5RFJJZ3C', 'A1Y0QSRN3Z91C', 'A1MUILE70L0N2J', 'A2GXFKBVRPSYIK',
#        'A72QINHDQG5XU', 'A1BN3HNG4PZYTM'],
#       dtype='object', name='reviewerID', length=1235315)
# Index(['A1SNLWGLFXD70K', 'A1KJ4CVG87QW09', 'AA9ITO6ZLZW6', 'APJ5ULJ1RMZ4',
#        'A2PAVURT4NOHE1', 'A3URQ0LXLV46E9', 'A2681T699HV6H1', 'A2EPSZKEG06QZE',
#        'A23K73OVXJ04EG', 'A2182SHKEJLY7N',
#        ...
#        'A3MG6W50A24W2T', 'A1I9BZNX6PHG29', 'A3G7PAS30Q3VPF', 'A265KF0CQ058RZ',
#        'A1GWSJTB780FGJ', 'A1XNL3C5RL8AC', 'A1BV7953RLM07E', 'A1ZUS94QF43DAC',
#        'A32T585IZ0DJX2', 'A1CYT9JXQXPFDD'],
#       dtype='object', name='reviewerID', length=3268694)
# Index(['A1BNZ90HN39TYR', 'A9DUCBTL8K3E4', 'AA8O583KRYINX', 'A16CR5RCPXFMMA',
#        'A398X3UMHLCM93', 'A14JYXSTIUTXP', 'A1PJ3XCSKTWWWG', 'A1Q4SCKKL5FRQF',
#        'A24ROB2LAIF4O9', 'A2RVOCG9HV376V',
#        ...
#        'A1UQBFCERIP7VJ', 'A3S6SXISF76BDD', 'ATCQ01H461WQT', 'A3S6SXISF76BDD',
#        'AG9TJLJUN5OM3', 'AGRJ3SRUYQOF8', 'A2YGGF3929H3IC', 'A3IXXERDW8EYZI',
#        'ACX42MH818TLY', 'A22UHERHRWEB78'],
#       dtype='object', name='reviewerID', length=1926046)
# Index(['A3C9CSW3TJITGT', 'A31POTIYCKSZ9G', 'A2GGHHME9B6W4O', 'A1FSLDH43ORWZP',
#        'A3NXHTSEBX9YHB', 'AYVR1MQCTNU5D', 'A3CJHKFHHQJP2K', 'A3638FINP26E8N',
#        'AUT7723O49VMN', 'A27GZ92KLXDJVJ',
#        ...
#        'AFLVOJKZWXBA7', 'AU6HK20YZQATN', 'A29FZGOSFJU1RP', 'AVJ4N5LBKAOG5',
#        'A2HJSR00979T5Z', 'A3SDSFPFY8WS8C', 'AME8WUWDTACFF', 'AJ062DSRHW9RX',
#        'A3JB0C3QWIN61Q', 'AVJ84HKPIGBMH'],
#       dtype='object', name='reviewerID', length=2252770)
# Index(['A24SSUT5CSW8BH', 'AK3V0HEBJMQ7J', 'A10BECPH7W8HM7', 'A2PRV9OULX1TWP',
# A31ZJPGGIEX3SV  Video_Games
# A221V1CP1DVGRI  Video_Games
# ATNN4DDRIT7Y5   Video_Games
# AI2SHH1PWGEUJ   Video_Games
# A1Z4X200ED17R4  Video_Games
# A129SW886TYQ6H  Video_Games
# A1SRVJNFWR0U9J  Video_Games
# A2BY4WCZRIM2UM  Video_Games
# A25C0NYV8WD775  Video_Games
# ...                     ...
# AGV7DRPGUQRRJ   Video_Games
# A3LEQOLIXQU7KS  Video_Games
# A1VJX9LLHAPQN7  Video_Games
# AYHRWER9LHSQO   Video_Games
# A3HHEI8P524Z1L  Video_Games
# A22GB5VTPH4MKG  Video_Games
# A2TCG2HV1VJP6V  Video_Games
# A3W4D8XOGLWUN5  Video_Games
# A3W4D8XOGLWUN5  Video_Games
# A2LQCBLLJVVR5T  Video_Games
# A2WQ4BJQF1YOI9  Video_Games
# ADTR71JUMGSF5   Video_Games
# A3LEQOLIXQU7KS  Video_Games
# A3J5Z8URA4ESX6  Video_Games
# A3LEQOLIXQU7KS  Video_Games
# A1YMF4FSUTAH3O  Video_Games
# A29TFK686ZE6D7  Video_Games
# A32Y506949BYW9  Video_Games
# A2FDUH8LZBYS7G  Video_Games
# A1K7X23UDT0R7V  Video_Games
# A2W3LGGHQW6XIS  Video_Games
# A2RGTYLFK1LY2L  Video_Games
# AEEMJX418B5RC   Video_Games
# A265KF0CQ058RZ  Video_Games
# A20J2PMC9ZPD4F  Video_Games
# A3HMVWAGUCNA1K  Video_Games
# A14H2HEWFT7CLQ  Video_Games
# A2EHIE51TERF2C  Video_Games
# A39GDUJP1737E1  Video_Games
# A3LEQOLIXQU7KS  Video_Games
#
# [1324752 rows x 5 columns]

# %% [markdown]
# ###### Adding reviewertext features such as character_count and word_count to the Reviews dataframe list

# %%
def calculate_charcount(row):
    return len(row['reviewText'])

# %%
for i in range(24):
    subset = (df_AzReviews[i]['reviewText'].notnull())
    suspect = pd.DataFrame()
    suspect = df_AzReviews[i][subset]
    
    df_AzReviews[i]['charcount_reviewtext'] = suspect.apply(calculate_charcount,axis=1)
#   print(df_AzReviews[i])

# %%
def calculate_wordcount(row):
    return len(row['reviewText'].split())

# %%
for i in range(24):
    subset = (df_AzReviews[i]['reviewText'].notnull())
    suspect = pd.DataFrame()
    suspect = df_AzReviews[i][subset]
    
    df_AzReviews[i]['wordcount_reviewtext'] = suspect.apply(calculate_wordcount,axis=1)
#   print(df_AzReviews[i])

# %%
df_AzReviews[16]
# Out:
#                 overall  unixReviewTime   reviewTime  \
# reviewerID
# A2IBPI20UZIR0U      5.0      1393545600  02 28, 2014
# A14VAT5EAX3D9S      5.0      1363392000  03 16, 2013
# A195EZSQDW3E21      5.0      1377648000  08 28, 2013
# A2C00NNG1ZQQG2      5.0      1392336000  02 14, 2014
# A94QU4C90B1AX       5.0      1392940800  02 21, 2014
# A2A039TZMZHH9Y      5.0      1356048000  12 21, 2012
# A1UPZM995ZAH90      5.0      1390089600  01 19, 2014
# AJNFQI3YR6XJ5       3.0      1353024000  11 16, 2012
# A146H4KN4LFR60  I put these strings on my Guild acoustic elect...
# A3A7Y3TSPPZU9T  I ordered this for my husband, the musician.  ...
# A30J7WQV0ZNRXG  I had used Elixer strings for several years on...
# A3M1PLEYNDEYO8  True to phosphor bronze these strings have a m...
# A1SD1C8XK3Z3V1  I've used Elixirs for about five years now. Th...
# A2VRAT69JDAD3W  I'm a D'Addario man myself, but hey free is fr...
# A306NASGVUDFKF  I really like these strings.  While they are n...
# A1TSKKBNV38E8Y  I have lots of friends who play these strings....
# A14B2YH83ZXMPP            Great, just as expected.  Thank to all.
# A1RPTVW5VEOSI   I've been thinking about trying the Nanoweb st...
# AWCJ12KBO5VII   I have tried coated strings in the past ( incl...
# A2Z7S8B5U4PAKJ  Well, MADE by Elixir and DEVELOPED with Taylor...
# A2WA8TDCTGUADI  These strings are really quite good, but I wou...
#
#                                                     reviewerName  \
# reviewerID
# A2IBPI20UZIR0U  cassandra tu "Yeah, well, that's just like, u...
# A14VAT5EAX3D9S                                              Jake
# A195EZSQDW3E21                     Rick Bennette "Rick Bennette"
# A2C00NNG1ZQQG2                         RustyBill "Sunday Rocker"
# A94QU4C90B1AX                                      SEAN MASLANKA
# A2A039TZMZHH9Y                               Bill Lewey "blewey"
# A1UPZM995ZAH90                                             Brian
# AJNFQI3YR6XJ5                                  Fender Guy "Rick"
# A3M1PLEYNDEYO8                                   G. Thomas "Tom"
# AMNTZU1YQN1TH                                        Kurt Robair
# A2NYK9KWFMJV4Y                       Mike Tarrani "Jazz Drummer"
# A35QFQI0M46LWO                                     Christopher C
# A2NIT6BKW11XJQ                                               Jai
# A1C0O09LOLVI39                                           Michael
# A17SLR18TUMULM                                       Straydogger
# A2PD27UKAD3Q00              Wilhelmina Zeitgeist "coolartsybabe"
# AKSFZ4G1AXYFC                                       C.E. "Frank"
# A67OJZLHBBUQ9                   Charles F. Marks "charlie marks"
# A2EZWZ8MBEDOLN                                            Charlo
# A1CL807EOUPVP1                                           GunHawk
# A1GMWTGXW682GB                                          MetalFan
# A2G12DY50U700V                                       Ricky Shows
# A3E0CF25A7LD2                                             WBowie
# A2W3CLAYZLDPTV                         Amazon Customer "=Chris="
# A398X9POBHK69N                                   Ann Vande Zande
# AXWB93VKVML6K                                     Michael Hassey
# A2FZ4Z0UFA1OR8                                               Pat
# AXP9CF1UTFRSU                                               tada
# A2CCGGDGZ694CT                                          b carney
# A27DR1VO079F1V                                         Dan Edman
# ...                                                          ...
# A31RULW0KNYJ5H                                                LA
# A3KZEGBTPH6MMF                                  Lucy Cat "Mandy"
# AWCJ12KBO5VII                                   Michael L. Knapp
# A29B4PAIOL7HYG                          N. Caruso "gibsonjunkie"
# A27L5L6I7OSV5B                                      Otto Correct
# AOMEH9W6LHC4S                                           Personne
# A3VDSGNIS92OVZ                               P. Hamm "p-squared"
# A27H0T39U3FZB5                        P. MSakamoto "boy clothes"
# A2PD27UKAD3Q00              Wilhelmina Zeitgeist "coolartsybabe"
# A146H4KN4LFR60                                         angelfood
# A1TSKKBNV38E8Y                   280
# A29B4PAIOL7HYG                   402
# A3VDSGNIS92OVZ                   169
# A146H4KN4LFR60                   120
# A3A7Y3TSPPZU9T                    28
# A30J7WQV0ZNRXG                   182
# A3M1PLEYNDEYO8                   117
# A1SD1C8XK3Z3V1                   116
# A2VRAT69JDAD3W                    98
# A306NASGVUDFKF                    79
# A1TSKKBNV38E8Y                   416
# A14B2YH83ZXMPP                     7
# A1RPTVW5VEOSI                    574
# AWCJ12KBO5VII                    120
# A2Z7S8B5U4PAKJ                   312
# A2WA8TDCTGUADI                   106
#
# [10234 rows x 12 columns]

# %% [markdown]
# ###### Adding helpful column features such as helpful_numerator, helpful_denominator and helpful_percentage to the Reviews dataframe list

# %%
for i in range(24):
    df_AzReviews[i]['helpful_numerator'] = [helpful_Numbers[0] for helpful_Numbers in df_AzReviews[i]['helpful']]
    df_AzReviews[i]['helpful_denominator'] = [helpful_Numbers[1] for helpful_Numbers in df_AzReviews[i]['helpful']]
    df_AzReviews[i]['helpfulpercentage'] = [(np.divide(helpful_Numbers[0],helpful_Numbers[1])* 100) for helpful_Numbers in df_AzReviews[i]['helpful']]

# %%
df_AzReviews[0]
# Out:
#                 overall  unixReviewTime   reviewTime  \
# reviewerID
# A11N155CW1UV02      2.0      1399075200   05 3, 2014
# A3BC8O2KCL29V2      5.0      1346630400   09 3, 2012
# A60D5HQFOTSOM       1.0      1381881600  10 16, 2013
# A1RJPIGRSNX4PW      4.0      1383091200  10 30, 2013
# A16XRPF40679KG      5.0      1234310400  02 11, 2009
# A1POFVVXUZR3IQ      5.0      1318291200  10 11, 2011
# A1PG2VV4W1WRPL      3.0      1381795200  10 15, 2013
# ATASGS8HZHGIB       3.0      1388275200  12 29, 2013
# A3RXD7Z44T9DHW      5.0      1393372800  02 26, 2014
# AUX8EUBNTHIIU       3.0      1396396800   04 2, 2014
# AXM3GQLD0CHIL       4.0      1391731200   02 7, 2014
# A398QSASJOIKA6      4.0      1391644800   02 6, 2014
# A2U61O0KWJH3MM      3.0      1378339200   09 5, 2013
# A2LSZFEFTDRDIJ      3.0      1371168000  06 14, 2013
# A39F2EW27YYUDM      5.0      1398729600  04 29, 2014
# AO1Z63O9CTT95       2.0      1394064000   03 6, 2014
# A1378ZJMWCTVT3      3.0      1389225600   01 9, 2014
# A2JE0JYIZL5NU4      3.0      1400371200  05 18, 2014
# A2LSZFEFTDRDIJ      5.0      1360454400  02 10, 2013
# A3RXD7Z44T9DHW      5.0      1394064000   03 6, 2014
# AAWV26JJ1SGS0       3.0      1392249600  02 13, 2014
# AS2AMJR6JJZSS       5.0      1391817600   02 8, 2014
# AXM3GQLD0CHIL       5.0      1366761600  04 24, 2013
# AYCGI5JRRISTJ       5.0      1362787200   03 9, 2013
# A1939G7K0LLQ8P      3.0      1333929600   04 9, 2012
# A2LUBUMIQEVWD3      3.0      1388620800   01 2, 2014
# A3DG93E8TXMKZF      3.0      1395446400  03 22, 2014
# ALLV1OUJL3WN6       5.0      1350604800  10 19, 2012
# ACBMCM7S32FZX                   1203                   214                  7
# A2HVL790PBWYTU                  6339                  1102                  0
# A2EKSOLTKBGWTK                  1013                   178                  2
# A1ELO9LMSE1CQ7                   150                    31                  0
# AGOEKVIJV9UX6                   2111                   368                 13
# A3I291BE0RNZCU                   879                   168                  0
# A1MNITZRYU71IO                   173                    36                  1
# A1XMHK9HN5MW2H                   393                    78                  3
#
#                 helpful_denominator  helpfulpercentage
# reviewerID
# A11N155CW1UV02                    0                NaN
# A3BC8O2KCL29V2                    0                NaN
# A60D5HQFOTSOM                     1           0.000000
# A1RJPIGRSNX4PW                    0                NaN
# A16XRPF40679KG                    1         100.000000
# A1POFVVXUZR3IQ                   12         100.000000
# A1PG2VV4W1WRPL                    0                NaN
# ATASGS8HZHGIB                     0                NaN
# A3RXD7Z44T9DHW                    0                NaN
# AUX8EUBNTHIIU                     0                NaN
# AXM3GQLD0CHIL                     0                NaN
# A398QSASJOIKA6                    0                NaN
# A2U61O0KWJH3MM                    1           0.000000
# A2LSZFEFTDRDIJ                    0                NaN
# A39F2EW27YYUDM                    0                NaN
# AO1Z63O9CTT95                     0                NaN
# A1378ZJMWCTVT3                    0                NaN
# A2JE0JYIZL5NU4                    0                NaN
# A2LSZFEFTDRDIJ                    0                NaN
# A3RXD7Z44T9DHW                    0                NaN
# AAWV26JJ1SGS0                     0                NaN
# AS2AMJR6JJZSS                     0                NaN
# AXM3GQLD0CHIL                     0                NaN
# AYCGI5JRRISTJ                     0                NaN
# A1939G7K0LLQ8P                    0                NaN
# A2LUBUMIQEVWD3                    0                NaN
# A3DG93E8TXMKZF                    2          50.000000
# ALLV1OUJL3WN6                     0                NaN
# A2MOIORZE53NL8                    0                NaN
# ALZWY9L4E5GXO                     0                NaN
# ...                             ...                ...
# AHMC83K2KE2JQ                     4          50.000000
# AQJU6UYGZLTIR                     0                NaN
# A1MGXQJVQQAN6T                    1           0.000000
# A1XMHK9HN5MW2H                    0                NaN
# A3OD04P0A831WB                    5          20.000000
# A3IDBWT605PTL7                    2          50.000000
# AWKRTLXGSNRES                     0                NaN
# A3LGDXHXYBMGCY                   11          81.818182
# A1Z4FX39G748CN                    2          50.000000
# A3QLAOOTFEHCJI                    4          75.000000
# A1TPW86OHXTXFC                    1         100.000000
# A10D7V3T60AHDC                    0                NaN
# A3VO05LD5WSO9F                    0                NaN
# AYB0IXBPBJ20A                    16         100.000000
# A1IH0F8NJIL8E3                    1           0.000000
# A6T098A9B0GZC                     2           0.000000
# A2RLZ2VD2AT8DL                    6          16.666667
# A3U3RFL0XE4F7V                    9          66.666667
# A3OD04P0A831WB                    1           0.000000
# A1S1BJFTA644TU                    5          80.000000
# AW3VZ5O895LRK                     7          85.714286
# A3DN9249F3X716                    9          77.777778
# ACBMCM7S32FZX                    16          43.750000
# A2HVL790PBWYTU                    0                NaN
# A2EKSOLTKBGWTK                    6          33.333333
# A1ELO9LMSE1CQ7                    0                NaN
# AGOEKVIJV9UX6                    15          86.666667
# A3I291BE0RNZCU                    2           0.000000
# A1MNITZRYU71IO                    1         100.000000
# A1XMHK9HN5MW2H                    4          75.000000
#
# [36797 rows x 15 columns]

# %% [markdown]
# ###### Adding time series features such as reviewYear, reviewMonth, reviewDate and reviewDayofWeek to the Reviews and Ratings DataFrame lists

# %%
for i in range(24):
    df_AzReviews[i]['ReviewYear'] = [datetime.datetime.utcfromtimestamp(reviewtime).year for reviewtime in df_AzReviews[i]['unixReviewTime']]
    df_AzReviews[i]['ReviewMonth'] = [datetime.datetime.utcfromtimestamp(reviewtime).month for reviewtime in df_AzReviews[i]['unixReviewTime']]
    df_AzReviews[i]['ReviewDate'] = [datetime.datetime.utcfromtimestamp(reviewtime).day for reviewtime in df_AzReviews[i]['unixReviewTime']]
    df_AzReviews[i]['ReviewDayofWeek'] = [datetime.datetime.utcfromtimestamp(reviewtime).weekday() for reviewtime in df_AzReviews[i]['unixReviewTime']]

# %%
df_AzReviews[23]
# Out:
#                 overall  unixReviewTime   reviewTime  \
# reviewerID
# A2HD75EMZR8QLN      1.0      1341792000   07 9, 2012
# A3UR8NLLY1ZHCX      4.0      1372550400  06 30, 2013
# A1INA0F5CWW3J4      1.0      1403913600  06 28, 2014
# A1DLMTOTHQ4AST      3.0      1315958400  09 14, 2011
# A361M14PU2GUEG      4.0      1308009600  06 14, 2011
# A2UTRVO4FDCBH6      4.0      1368230400  05 11, 2013
# AN3YYDZAS3O1Y       5.0      1313280000  08 14, 2011
# AQTC623NCESZW       1.0      1353715200  11 24, 2012
# A1QJJU33VNC4S7      4.0      1352851200  11 14, 2012
# A2JLT2WY0F2HVI      2.0      1391817600   02 8, 2014
# A38NXTZUFB1O2K      5.0      1309219200  06 28, 2011
# ANW6EGY12V5XS       5.0      1318982400  10 19, 2011
# AHT34BRYFBFT1       5.0      1388275200  12 29, 2013
# A248LSBZT4P38V      1.0      1404086400  06 30, 2014
# AFS6WERAP409A       1.0      1367280000  04 30, 2013
# A14L115LBOB0A5      1.0      1373846400  07 15, 2013
# A20DRRKAN5Z9Q       4.0      1332115200  03 19, 2012
# A2VYL51WQXC5KK      3.0      1372377600  06 28, 2013
# A10AYT89XSCE46      1.0      1324857600  12 26, 2011
# A29KT7UP7DLM1J      1.0      1385164800  11 23, 2013
# A15PIAQT55GNCA      5.0      1308355200  06 18, 2011
# A18YFCLL3GBD0T      1.0      1315958400  09 14, 2011
# A1BHRNLW2L8KLD      2.0      1373500800  07 11, 2013
# A1CB8HH9YJ2YZE      3.0      1339200000   06 9, 2012
# A2LQCBLLJVVR5T      5.0      1307923200  06 13, 2011
# A37M0B3NHDHN9V      4.0      1334016000  04 10, 2012
# A2QQ9KSQ44QZSE      5.0      1258588800  11 19, 2009
# A2PJOSU5ND84S1      5.0      1396656000   04 5, 2014
# A91BVZEDZYEWW       5.0      1297555200  02 13, 2011
# A1PH1BOQGD7SCA      5.0      1403827200  06 27, 2014
# ...                 ...             ...          ...
# A1ZR8AIM298DFT      1.0      1404864000   07 9, 2014
# AKCXS6JVW6E8L       5.0      1402272000   06 9, 2014
#
#                 ReviewMonth  ReviewDate  ReviewDayofWeek
# reviewerID
# A2HD75EMZR8QLN            7           9                0
# A3UR8NLLY1ZHCX            6          30                6
# A1INA0F5CWW3J4            6          28                5
# A1DLMTOTHQ4AST            9          14                2
# A361M14PU2GUEG            6          14                1
# A2UTRVO4FDCBH6            5          11                5
# AN3YYDZAS3O1Y             8          14                6
# AQTC623NCESZW            11          24                5
# A1QJJU33VNC4S7           11          14                2
# A2JLT2WY0F2HVI            2           8                5
# A38NXTZUFB1O2K            6          28                1
# ANW6EGY12V5XS            10          19                2
# AHT34BRYFBFT1            12          29                6
# A248LSBZT4P38V            6          30                0
# AFS6WERAP409A             4          30                1
# A14L115LBOB0A5            7          15                0
# A20DRRKAN5Z9Q             3          19                0
# A2VYL51WQXC5KK            6          28                4
# A10AYT89XSCE46           12          26                0
# A29KT7UP7DLM1J           11          23                5
# A15PIAQT55GNCA            6          18                5
# A18YFCLL3GBD0T            9          14                2
# A1BHRNLW2L8KLD            7          11                3
# A1CB8HH9YJ2YZE            6           9                5
# A2LQCBLLJVVR5T            6          13                0
# A37M0B3NHDHN9V            4          10                1
# A2QQ9KSQ44QZSE           11          19                3
# A2PJOSU5ND84S1            4           5                5
# A91BVZEDZYEWW             2          13                6
# A1PH1BOQGD7SCA            6          27                4
# ...                     ...         ...              ...
# A1ZR8AIM298DFT            7           9                2
# AKCXS6JVW6E8L             6           9                0
# A31ARER1KVHZB             7          10                3
# A10584T58O3B5Y            6          13                4
# A3E89VW74Z8TK8            6          18                2
# A1DDGFYGFY6TDC            6           9                0
# A1ZE1LPZHGG1QP            6          20                4
# A3Q4NULWZU3RI             6           9                0
# A2JGUR1STLMXZT            6          12                3
# AQOFQWJYJRA5W             6          15                6
# A2YSY26ZVMNNV2            6          10                1
# A2VCOIPPA48ICC            6          17                1
# A1GT9H5GAYR3F0            7           4                4
# A26EF0FFHL68HP            6          22                6
# A3RPNJODORTLRB            6          10                1
# A1XNZ7PCE45KK7            6          10                1
# A25NSTXNN16KG8            6           9                0
# A37T2MU6L4521N            6          22                6
# A3D8VPZNKYIAP0            6           9                0
# AJQB6I00X8WAI             6          24                1
# A1MHB1HRR6VPEH            6          14                5
# A2IGEPJJYKMOWK            7          19                5
# A1M19BGTJ5PI1I            6           9                0
# A3PG9EEZMT9CJF            6          13                4
# A1V6WWYN2S6V40            5          31                5
# A1ICREREXO9J81            7          20                6
# A3VVMIMMTYQV5F            6          21                5
# A1DD4B97M4DUC5            5          29                3
# A2Q9CNJ4T6ZK99            6           2                0
# A27CD59R5U58GG            6           4                2
#
# [228967 rows x 19 columns]

# %%
for i in range(24):
    df_AzRatings[i]['ReviewYear'] = [datetime.datetime.utcfromtimestamp(reviewtime).year for reviewtime in df_AzRatings[i]['unixReviewTime']]
    df_AzRatings[i]['ReviewMonth'] = [datetime.datetime.utcfromtimestamp(reviewtime).month for reviewtime in df_AzRatings[i]['unixReviewTime']]
# A39GDUJP1737E1  Video_Games        2014            7          14
# A3LEQOLIXQU7KS  Video_Games        2014            7          12
#
#                 ReviewDayofWeek
# reviewerID
# A24SSUT5CSW8BH                5
# AK3V0HEBJMQ7J                 3
# A10BECPH7W8HM7                3
# A2PRV9OULX1TWP                2
# AE7GUHCDQQ4UI                 2
# A48ABFDDRMKI8                 4
# A26B0P6K95SIKW                0
# AZ3UWOC8QSO6C                 3
# A182S3ANC0W7DL                2
# AY5Q951JAZAX9                 1
# A1TL721YECDIM8                1
# APDCEJMFDO2YT                 0
# AFJ7A9CSEPZNY                 1
# A14YVGE643TRJK                1
# A2H3TQWU51W1WE                0
# A3KO10N2ODLHBR                0
# A1T98OCCYW6OBI                2
# A3P758JGM12DD7                4
# A1TBUSGCBTXWFC                6
# A366EUKI8WMGYB                2
# A2VBOZL2J83PCG                2
# A31ZJPGGIEX3SV                6
# A221V1CP1DVGRI                6
# ATNN4DDRIT7Y5                 5
# AI2SHH1PWGEUJ                 3
# A1Z4X200ED17R4                3
# A129SW886TYQ6H                0
# A1SRVJNFWR0U9J                0
# A2BY4WCZRIM2UM                2
# A25C0NYV8WD775                1
# ...                         ...
# AGV7DRPGUQRRJ                 2
# A3LEQOLIXQU7KS                5
# A1VJX9LLHAPQN7                1
# AYHRWER9LHSQO                 1
# A3HHEI8P524Z1L                0
# A22GB5VTPH4MKG                2
# A2TCG2HV1VJP6V                2
# A3W4D8XOGLWUN5                3
# A3W4D8XOGLWUN5                6
# A2LQCBLLJVVR5T                1
# A2WQ4BJQF1YOI9                2
# ADTR71JUMGSF5                 1
# A3LEQOLIXQU7KS                5
# A3J5Z8URA4ESX6                5
# A3LEQOLIXQU7KS                0
# A1YMF4FSUTAH3O                6
# A29TFK686ZE6D7                0
# A32Y506949BYW9                0
# A2FDUH8LZBYS7G                0
# A1K7X23UDT0R7V                0
# A2W3LGGHQW6XIS                5
# A2RGTYLFK1LY2L                2
# AEEMJX418B5RC                 5
# A265KF0CQ058RZ                1
# A20J2PMC9ZPD4F                0
# A3HMVWAGUCNA1K                1
# A14H2HEWFT7CLQ                0
# A2EHIE51TERF2C                0
# A39GDUJP1737E1                0
# A3LEQOLIXQU7KS                5
#
# [1324752 rows x 9 columns]

# %% [markdown]
# # End of Working on Entire Dataset for adding Data Features/Columns and cleanup Section

# %% [markdown]
# # Start of Data Visualization Section on Smaller DataSet

# %%
# %matplotlib inline

# %%
sus2 = (df_AA5_head['wordcount_reviewtext'].notnull() & df_AA5_head['overall'].notnull())

suspect2 = df_AA5_head.loc[sus2]
suspect2
# Out:
#                 overall  unixReviewTime   reviewTime  \
# reviewerID
# A1N4O8VOJZTDVB      3.0      1383350400   11 2, 2013
# A2HQWU6HUKIEC7      5.0      1323043200   12 5, 2011
# A1SXASF6GYG96I      5.0      1337558400  05 21, 2012
# A2B54P9ZDYH167      5.0      1354752000   12 6, 2012
# AFOFZDTX5UC6D       5.0      1391212800   02 1, 2014
#
#                                                           summary  \
# reviewerID
# A1N4O8VOJZTDVB                                        Really cute
# A2HQWU6HUKIEC7                                2-year-old loves it
# A1SXASF6GYG96I                                           Fun game
# A2B54P9ZDYH167                               We love our Monkeys!
# AFOFZDTX5UC6D   This is my granddaughters favorite app on my K...
#
#                     reviewerID helpful        asin  \
# reviewerID
# A1N4O8VOJZTDVB  A1N4O8VOJZTDVB  [1, 1]  B004A9SDD8
# A2HQWU6HUKIEC7  A2HQWU6HUKIEC7  [0, 0]  B004A9SDD8
# A1SXASF6GYG96I  A1SXASF6GYG96I  [0, 0]  B004A9SDD8
# A2B54P9ZDYH167  A2B54P9ZDYH167  [3, 4]  B004A9SDD8
# AFOFZDTX5UC6D    AFOFZDTX5UC6D  [1, 1]  B004A9SDD8
#
#                                                        reviewText  \
# reviewerID
# A1N4O8VOJZTDVB  Loves the song, so he really couldn't wait to ...
# A2HQWU6HUKIEC7  Oh, how my little grandson loves this app. He'...
# A1SXASF6GYG96I  I found this at a perfect time since my daught...
# A2B54P9ZDYH167  My 1 year old goes back to this game over and ...
# AFOFZDTX5UC6D   There are three different versions of the song...
#
#                                  reviewerName   ProductType  \
# reviewerID
# A1N4O8VOJZTDVB                 Annette Yancey  Android Apps
# A2HQWU6HUKIEC7        Audiobook lover "Kathy"  Android Apps
# A1SXASF6GYG96I                  Barbara Gibbs  Android Apps
# A2B54P9ZDYH167  Brooke Greenstreet "Babylove"  Android Apps
# AFOFZDTX5UC6D                      C. Galindo  Android Apps
#
#                 charcount_reviewtext  helpfulpercentage  helpful_numerator  \
# reviewerID
# A1N4O8VOJZTDVB                   206              100.0                1.0
# A2HQWU6HUKIEC7                   255                NaN                NaN
# A1SXASF6GYG96I                   288                NaN                NaN
# A2B54P9ZDYH167                   186               75.0                3.0
# AFOFZDTX5UC6D                    746              100.0                1.0
#
#                 helpful_denominator  wordcount_reviewtext  ReviewYear  \
# reviewerID
# A1N4O8VOJZTDVB                  1.0                    41        2013
# A2HQWU6HUKIEC7                  NaN                    47        2011
# A1SXASF6GYG96I                  NaN                    52        2012
# A2B54P9ZDYH167                  4.0                    40        2012
# AFOFZDTX5UC6D                   1.0                   134        2014
#
#                 ReviewMonth  ReviewDay ReviewDayofWeek
# reviewerID
# A1N4O8VOJZTDVB           11          2        Saturday
# A2HQWU6HUKIEC7           12          5          Monday
# A1SXASF6GYG96I            5         21          Monday
# A2B54P9ZDYH167           12          6        Thursday
# AFOFZDTX5UC6D             2          1        Saturday

# %%
fig, ax = plt.subplots()
ax.scatter(suspect2['wordcount_reviewtext'], suspect2['overall'].dropna(), color = 'darkgreen', marker='^')
plt.show()

# %%
sus3 = (df_AA5_head['helpful_denominator'].notnull() & df_AA5_head['overall'].notnull())

suspect3 = df_AA5_head.loc[sus3]
suspect3
# Out:
#                 overall  unixReviewTime  reviewTime  \
# reviewerID
# A1N4O8VOJZTDVB      3.0      1383350400  11 2, 2013
# A2B54P9ZDYH167      5.0      1354752000  12 6, 2012
# AFOFZDTX5UC6D       5.0      1391212800  02 1, 2014
#
#                                                           summary  \
# reviewerID
# A1N4O8VOJZTDVB                                        Really cute
# A2B54P9ZDYH167                               We love our Monkeys!
# AFOFZDTX5UC6D   This is my granddaughters favorite app on my K...
#
#                     reviewerID helpful        asin  \
# reviewerID
# A1N4O8VOJZTDVB  A1N4O8VOJZTDVB  [1, 1]  B004A9SDD8
# A2B54P9ZDYH167  A2B54P9ZDYH167  [3, 4]  B004A9SDD8
# AFOFZDTX5UC6D    AFOFZDTX5UC6D  [1, 1]  B004A9SDD8
#
#                                                        reviewText  \
# reviewerID
# A1N4O8VOJZTDVB  Loves the song, so he really couldn't wait to ...
# A2B54P9ZDYH167  My 1 year old goes back to this game over and ...
# AFOFZDTX5UC6D   There are three different versions of the song...
#
#                                  reviewerName   ProductType  \
# reviewerID
# A1N4O8VOJZTDVB                 Annette Yancey  Android Apps
# A2B54P9ZDYH167  Brooke Greenstreet "Babylove"  Android Apps
# AFOFZDTX5UC6D                      C. Galindo  Android Apps
#
#                 charcount_reviewtext  helpfulpercentage  helpful_numerator  \
# reviewerID
# A1N4O8VOJZTDVB                   206              100.0                1.0
# A2B54P9ZDYH167                   186               75.0                3.0
# AFOFZDTX5UC6D                    746              100.0                1.0
#
#                 helpful_denominator  wordcount_reviewtext  ReviewYear  \
# reviewerID
# A1N4O8VOJZTDVB                  1.0                    41        2013
# A2B54P9ZDYH167                  4.0                    40        2012
# AFOFZDTX5UC6D                   1.0                   134        2014
#
#                 ReviewMonth  ReviewDay ReviewDayofWeek
# reviewerID
# A1N4O8VOJZTDVB           11          2        Saturday
# A2B54P9ZDYH167           12          6        Thursday
# AFOFZDTX5UC6D             2          1        Saturday

# %%
fig, ax = plt.subplots()
ax.scatter( suspect3['helpful_denominator'].dropna(), suspect3['overall'].dropna(), color = 'darkgreen', marker='^')
plt.show()

# %% [markdown]
# ###### Histogram of overall counts

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")

#mdfh = sns.load_dataset("merged_df_AA5_head")
#g = sns.FacetGrid(mdfh, row="ReviewYear", col="overall", margin_titles=True)
#bins = np.linspace(0, 60, 13)


#n_data = len(merged_df_AA5_head['overall'])
#n_bins = int(np.sqrt(n_data))
#print(n_bins)

_ = plt.hist(df_AA5_head['overall'])
_ = plt.title('overall score counts')
_ = plt.xlabel('overall score')
_ = plt.ylabel('count')

plt.show()
#g.map(plt.hist, "overall", color="steelblue", bins=bins, lw=0)

# %% [markdown]
# ###### Beeswarm plots using seaborn

# %%
_ = sns.swarmplot(x='ReviewDay', y='overall', data=df_AA5_head)
_ = plt.xlabel('ReviewDate')
_ = plt.ylabel('overall')
plt.show()

# %%
_ = sns.swarmplot(x='ReviewDayofWeek', y='overall', data=df_AA5_head)
_ = plt.xlabel('ReviewDayofWeek')
_ = plt.ylabel('overall')
plt.show()

# %%
_ = sns.swarmplot(x='ReviewMonth', y='overall', data=df_AA5_head)
_ = plt.xlabel('ReviewMonth')
_ = plt.ylabel('overall')
plt.show()

# %%
_ = sns.swarmplot(x='ReviewYear', y='overall', data=df_AA5_head)
_ = plt.xlabel('ReviewYear')
_ = plt.ylabel('overall')
plt.show()

# %%
_ = sns.swarmplot(x='overall', y='wordcount_reviewtext', data=df_AA5_head)
_ = plt.xlabel('overall')
_ = plt.ylabel('wordcount_reviewtext')
plt.show()

# %%
def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""

    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x

    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

# %%
# Compute ECDF for overall score: x_overall, y_overall
x_overall, y_overall = ecdf(df_AA5_head['overall'])

# Generate plot
_ = plt.plot(x_overall, y_overall, marker='.', linestyle='none')

# Make the margins nice
plt.margins(0.02)

# Label the axes
_ = plt.xlabel('overall')
_ = plt.ylabel('ECDF')

# Display the plot
plt.show()

# %%
import sys
sys.version
sys.version_info
# Out:
# sys.version_info(major=3, minor=5, micro=4, releaselevel='final', serial=0)

# %%
# install rpy2 using conda
#conda install rpy2 v 2.9 for python 3.54

# %%
uniform_data = (df_AA5_head['overall'],df_AA5_head['ReviewMonth'])
ax = sns.heatmap(uniform_data)

# %%
uniform_data = (df_AA5_head['overall'],df_AA5_head['wordcount_reviewtext'])
#uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data)

# %%
uniform_data = (df_AA5_head['wordcount_reviewtext'],df_AA5_head['overall'])
#uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data)

# %%
tempnewdf = df_AA5_head.dropna()
tempnewdf
# Out:
#                 overall  unixReviewTime  reviewTime  \
# reviewerID
# A1N4O8VOJZTDVB      3.0      1383350400  11 2, 2013
# A2B54P9ZDYH167      5.0      1354752000  12 6, 2012
# AFOFZDTX5UC6D       5.0      1391212800  02 1, 2014
#
#                                                           summary  \
# reviewerID
# A1N4O8VOJZTDVB                                        Really cute
# A2B54P9ZDYH167                               We love our Monkeys!
# AFOFZDTX5UC6D   This is my granddaughters favorite app on my K...
#
#                     reviewerID helpful        asin  \
# reviewerID
# A1N4O8VOJZTDVB  A1N4O8VOJZTDVB  [1, 1]  B004A9SDD8
# A2B54P9ZDYH167  A2B54P9ZDYH167  [3, 4]  B004A9SDD8
# AFOFZDTX5UC6D    AFOFZDTX5UC6D  [1, 1]  B004A9SDD8
#
#                                                        reviewText  \
# reviewerID
# A1N4O8VOJZTDVB  Loves the song, so he really couldn't wait to ...
# A2B54P9ZDYH167  My 1 year old goes back to this game over and ...
# AFOFZDTX5UC6D   There are three different versions of the song...
#
#                                  reviewerName   ProductType  \
# reviewerID
# A1N4O8VOJZTDVB                 Annette Yancey  Android Apps
# A2B54P9ZDYH167  Brooke Greenstreet "Babylove"  Android Apps
# AFOFZDTX5UC6D                      C. Galindo  Android Apps
#
#                 charcount_reviewtext  helpfulpercentage  helpful_numerator  \
# reviewerID
# A1N4O8VOJZTDVB                   206              100.0                1.0
# A2B54P9ZDYH167                   186               75.0                3.0
# AFOFZDTX5UC6D                    746              100.0                1.0
#
#                 helpful_denominator  wordcount_reviewtext  ReviewYear  \
# reviewerID
# A1N4O8VOJZTDVB                  1.0                    41        2013
# A2B54P9ZDYH167                  4.0                    40        2012
# AFOFZDTX5UC6D                   1.0                   134        2014
#
#                 ReviewMonth  ReviewDay ReviewDayofWeek
# reviewerID
# A1N4O8VOJZTDVB           11          2        Saturday
# A2B54P9ZDYH167           12          6        Thursday
# AFOFZDTX5UC6D             2          1        Saturday

# %%
score_data = tempnewdf.iloc[:,[0,11,12,13,14,15,16,17]]
score_data.reset_index(drop=True, inplace=True)
score_data
# Out:
#    overall  helpfulpercentage  helpful_numerator  helpful_denominator  \
# 0      3.0              100.0                1.0                  1.0
# 1      5.0               75.0                3.0                  4.0
# 2      5.0              100.0                1.0                  1.0
#
#    wordcount_reviewtext  ReviewYear  ReviewMonth  ReviewDay
# 0                    41        2013           11          2
# 1                    40        2012           12          6
# 2                   134        2014            2          1

# %%
#uniform_data = (merged_df_AA5_head.dropna())
#uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(score_data.dropna(),annot=True, fmt="g", cmap='viridis')

# %%
newdata = score_data.pivot("overall","ReviewYear","helpful_numerator")
ax = sns.heatmap(newdata,annot=True, fmt="g", cmap='YlGnBu')

# %%
sns.set(color_codes=True)
#iris = sns.load_dataset("score_data")
#species = iris.pop("overall")
g = sns.clustermap(score_data,metric="correlation",annot=True, fmt="g", cmap='YlGnBu')

# %%
sns.pairplot(score_data,hue='overall',palette='Set1')

# %% [markdown]
# # End of Data Visualization Section on Smaller DataSet

# %% [markdown]
# # Start of Data Visualization Section on Entire DataSet

# %%
df_AzReviews[0].columns
# Out:
# Index(['overall', 'unixReviewTime', 'reviewTime', 'summary', 'reviewerID',
#        'helpful', 'asin', 'reviewText', 'reviewerName', 'ProductType',
#        'charcount_reviewtext', 'wordcount_reviewtext', 'helpful_numerator',
#        'helpful_denominator', 'helpfulpercentage', 'ReviewYear', 'ReviewMonth',
#        'ReviewDate', 'ReviewDayofWeek'],
#       dtype='object')

# %%
fig, ax = plt.subplots()
ax.scatter(df_AzReviews[0]['wordcount_reviewtext'], df_AzReviews[0]['overall'].dropna(), color = 'darkgreen', marker='^')
_ = plt.title('Video Games')
# Label the axes
_ = plt.xlabel('wordcount_reviewtext')
_ = plt.ylabel('overall')
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter( df_AzReviews[0]['helpful_denominator'].dropna(), df_AzReviews[0]['overall'].dropna(), color = 'darkgreen', marker='^')
_ = plt.title('Video Games')
# Label the axes
_ = plt.xlabel('helpful_denominator')
_ = plt.ylabel('overall')
plt.show()

# %%
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex='col', sharey='row')
# , ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12
# ax13, ax14, ax15, ax16, ax17, ax18, ax19, ax20, ax21, ax22, ax23, ax24
f.suptitle('Sharing WordCount_ReviewText per column, OverallScore per row')
ax1.scatter(df_AzReviews[0]['wordcount_reviewtext'], df_AzReviews[0]['overall'])
ax2.scatter(df_AzReviews[1]['wordcount_reviewtext'], df_AzReviews[1]['overall'])
ax3.scatter(df_AzReviews[2]['wordcount_reviewtext'], df_AzReviews[2]['overall'], color='r')
ax4.scatter(df_AzReviews[3]['wordcount_reviewtext'], df_AzReviews[3]['overall'], color='r')
# ax5.scatter(df_AzReviews[4]['wordcount_reviewtext'], df_AzReviews[4]['overall'])
# ax6.scatter(df_AzReviews[5]['wordcount_reviewtext'], df_AzReviews[5]['overall'])
# ax7.scatter(df_AzReviews[6]['wordcount_reviewtext'], df_AzReviews[6]['overall'], color='r')
# ax8.scatter(df_AzReviews[7]['wordcount_reviewtext'], df_AzReviews[7]['overall'], color='r')
# ax9.scatter(df_AzReviews[8]['wordcount_reviewtext'], df_AzReviews[8]['overall'])
# ax10.scatter(df_AzReviews[9]['wordcount_reviewtext'], df_AzReviews[9]['overall'])
# ax11.scatter(df_AzReviews[10]['wordcount_reviewtext'], df_AzReviews[10]['overall'], color='r')
# ax12.scatter(df_AzReviews[11]['wordcount_reviewtext'], df_AzReviews[11]['overall'], color='r')
# ax13.scatter(df_AzReviews[12]['wordcount_reviewtext'], df_AzReviews[12]['overall'])
# ax14.scatter(df_AzReviews[13]['wordcount_reviewtext'], df_AzReviews[13]['overall'])
# ax15.scatter(df_AzReviews[14]['wordcount_reviewtext'], df_AzReviews[14]['overall'], color='r')
# ax16.scatter(df_AzReviews[15]['wordcount_reviewtext'], df_AzReviews[15]['overall'], color='r')
# ax17.scatter(df_AzReviews[16]['wordcount_reviewtext'], df_AzReviews[16]['overall'])
# ax18.scatter(df_AzReviews[17]['wordcount_reviewtext'], df_AzReviews[17]['overall'])
# ax19.scatter(df_AzReviews[18]['wordcount_reviewtext'], df_AzReviews[18]['overall'], color='r')
# ax20.scatter(df_AzReviews[19]['wordcount_reviewtext'], df_AzReviews[19]['overall'], color='r')
# ax21.scatter(df_AzReviews[20]['wordcount_reviewtext'], df_AzReviews[20]['overall'])
# ax22.scatter(df_AzReviews[21]['wordcount_reviewtext'], df_AzReviews[21]['overall'])
# ax23.scatter(df_AzReviews[22]['wordcount_reviewtext'], df_AzReviews[22]['overall'], color='r')
# ax24.scatter(df_AzReviews[23]['wordcount_reviewtext'], df_AzReviews[23]['overall'], color='r')

# %%
# import numpy as np
# import seaborn as sns
# # import matplotlib.pyplot as plt
# sns.set(style="darkgrid")

# mdfh = sns.load_dataset("df_AzReviews[0]")
# g = sns.FacetGrid(mdfh, row="ReviewYear", col="overall", margin_titles=True)
# bins = np.linspace(0, 60, 13)


# n_data = len(df_AzReviews[0]['overall'])
# n_bins = int(np.sqrt(n_data))
# # print(n_bins)

# _ = plt.hist(df_AzReviews[0]['overall'])
# _ = plt.title('Video Games overall score counts')
# _ = plt.xlabel('overall score')
# _ = plt.ylabel('count')

# # plt.show()
# g.map(plt.hist, "overall", color="steelblue", bins=bins, lw=0)

# %%
_ = sns.swarmplot(x='overall', y='ReviewDate', data=df_AzReviews[0])
_ = plt.xlabel('overall')
_ = plt.ylabel('ReviewDate')
plt.show()

# %%
_ = sns.swarmplot(x='ReviewDayofWeek', y='overall', data=df_AzReviews[0])
_ = plt.xlabel('ReviewDayofWeek')
_ = plt.ylabel('overall')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-135-0d0b36fb737d> in <module>()
# ----> 1 _ = sns.swarmplot(x='ReviewDayofWeek', y='overall', data=df_AzReviews[0])
#       2 _ = plt.xlabel('ReviewDayofWeek')
#       3 _ = plt.ylabel('overall')
#       4 plt.show()
#
# C:\Program Files\Anaconda33\lib\site-packages\seaborn\categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2798                        linewidth=linewidth))
#    2799
# -> 2800     plotter.plot(ax, kwargs)
#    2801     return ax
#    2802
#
# C:\Program Files\Anaconda33\lib\site-packages\seaborn\categorical.py in plot(self, ax, kws)
#    1433     def plot(self, ax, kws):
#    1434         """Make the full plot."""
# -> 1435         self.draw_swarmplot(ax, kws)
#    1436         self.add_legend_data(ax)
#    1437         self.annotate_axes(ax)
#
# C:\Program Files\Anaconda33\lib\site-packages\seaborn\categorical.py in draw_swarmplot(self, ax, kws)
#    1429         for center, swarm in zip(centers, swarms):
#    1430             if swarm.get_offsets().size:
# -> 1431                 self.swarm_points(ax, swarm, center, width, s, **kws)
#    1432
#    1433     def plot(self, ax, kws):
#
# C:\Program Files\Anaconda33\lib\site-packages\seaborn\categorical.py in swarm_points(self, ax, points, center, width, s, **kws)
#    1338
#    1339         # Do the beeswarm in point coordinates
# -> 1340         new_xy = self.beeswarm(orig_xy, d)
#    1341
#    1342         # Transform the point coordinates back to data coordinates
#
# C:\Program Files\Anaconda33\lib\site-packages\seaborn\categorical.py in beeswarm(self, orig_xy, d)
#    1300             # Find the first candidate that doesn't overlap any neighbours
#    1301             new_xy_i = self.first_non_overlapping_candidate(candidates,
# -> 1302                                                             neighbors, d)
#    1303
#    1304             # Place it into the swarm
#
# C:\Program Files\Anaconda33\lib\site-packages\seaborn\categorical.py in first_non_overlapping_candidate(self, candidates, neighbors, d)
#    1258             dy = neighbors_y - y_i
#    1259
# -> 1260             sq_distances = np.power(dx, 2.0) + np.power(dy, 2.0)
#    1261
#    1262             # good candidate does not overlap any of neighbors
#
# KeyboardInterrupt:

# %%
_ = sns.swarmplot(x='ReviewMonth', y='overall', data=df_AzReviews[0])
_ = plt.xlabel('ReviewMonth')
_ = plt.ylabel('overall')
plt.show()

# %%
_ = sns.swarmplot(x='ReviewYear', y='overall', data=df_AzReviews[0])
_ = plt.xlabel('ReviewYear')
_ = plt.ylabel('overall')
plt.show()

# %%
_ = sns.swarmplot(x='overall', y='wordcount_reviewtext', data=df_AzReviews[0])
_ = plt.xlabel('overall')
_ = plt.ylabel('wordcount_reviewtext')
plt.show()

# %%
def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""

    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x

    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

# %%
# Compute ECDF for overall score: x_overall, y_overall
x_overall, y_overall = ecdf(df_AzReviews[0]['overall'])

# Generate plot
_ = plt.plot(x_overall, y_overall, marker='.', linestyle='none')

# Make the margins nice
plt.margins(0.02)

# Label the axes
_ = plt.xlabel('overall')
_ = plt.ylabel('ECDF')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6f53ce78b0a8> in <module>()
#       1 # Compute ECDF for overall score: x_overall, y_overall
# ----> 2 x_overall, y_overall = ecdf(df_AzReviews[0]['overall'])
#       3
#       4 # Generate plot
#       5 _ = plt.plot(x_overall, y_overall, marker='.', linestyle='none')
#
# NameError: name 'df_AzReviews' is not defined

# %%
df_AzReviews[0].info()

# %%
score_data = df_AzReviews[0].dropna().iloc[:,[7,10,11,12,13,14,15,16,17,18]]
score_data.reset_index(drop=True, inplace=True)
score_data

# %%
ax = sns.heatmap(score_data,annot=True, fmt="g", cmap='viridis')

# %%
newdata = score_data.pivot("overall","ReviewYear","helpful_numerator")
ax = sns.heatmap(newdata,annot=True, fmt="g", cmap='YlGnBu')

# %%
sns.set(color_codes=True)
#iris = sns.load_dataset("score_data")
#species = iris.pop("overall")
g = sns.clustermap(score_data,metric="correlation",annot=True, fmt="g", cmap='YlGnBu')

# %%
sns.pairplot(score_data,hue='overall',palette='Set1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9fc2963f31d0> in <module>()
# ----> 1 sns.pairplot(score_data,hue='overall',palette='Set1')
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # End of Data Visualization Section on Entire DataSet

# %% [markdown]
# # NLTK and NLP Processing of ReviewText data

# %%
# wordcloud
# %matplotlib inline 

import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import nltk

data = open("sfgate.html",'r').read()
text = nltk.clean_html(data)
cleaned = nltk.word_tokenize(text.lower())
wordlist = [x for x in cleaned if (len(x)>=2 and x.isalpha())]
wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white').generate(" ".join(wordlist))
plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-f60ff1c1fea0> in <module>()
#       3
#       4 import matplotlib.pyplot as plt
# ----> 5 from wordcloud import WordCloud, STOPWORDS
#       6 import nltk
#       7
#
# ImportError: No module named 'wordcloud'

# %%
import rpy2.interactive.packages as p
import seaborn as sns
# %matplotlib inline

# %%
import rpy2.robjects as ro
import rpy2.robjects.numpy2ri
ro.numpy2ri.activate() 
R = ro.r
# %matplotlib inline
#R.heatmap(uniform_data.iloc[:,[0,1]])


data = np.random.random((10, 10))
# #R.png(file='/tmp/out.png')
R.heatmap(data)
#R.heatmap(np.array((merged_df_AA5_head['overall']).astype(int),(merged_df_AA5_head['overall']).astype(int)))
# R("dev.off()")

# %%
# ## load the R package ISLR
# infert = p.importr("ISLR")

# # load the Auto dataset
# auto_df = com.load_data('merged_df_AA5_head')

# # calculate the correlation matrix
# corr = auto_df.corr()

# # plot the heatmap
# sns.heatmap(corr, 
#         xticklabels=corr.columns,
#         yticklabels=corr.columns)

# %%
# Import necessary modules
import nltk

# %%
from nltk.tokenize import word_tokenize 
from nltk.tokenize import sent_tokenize

# %%
df_AA5_head['reviewText'][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-863a0340414c> in <module>()
# ----> 1 df_AA5_head['reviewText'][0]
#
# NameError: name 'df_AA5_head' is not defined

# %%
#import nltk
#nltk.download()

# %%
test = merged_df_AA5_head['reviewText']
test

# %%
merged_df_AA5_head.loc[:,['reviewText']]

# %%
for index, row in merged_df_AA5_head.iterrows():
    print(row['reviewText'])

# %%
allReviewText = ' '
for index, row in merged_df_AA5_head.iterrows():
#    print(type(row['reviewText']))
    if pd.notnull(row['reviewText']):
        allReviewText = allReviewText + row['reviewText']
print(allReviewText)

# %%
# Split merged_df_AA5_head into sentences: sentences
#sentences = sent_tokenize(merged_df_AA5_head['reviewText'][0])

# Use word_tokenize to tokenize the fourth sentence: tokenized_sent
#tokenized_sent = word_tokenize(sentences[0])

# Make a set of unique tokens in the entire scene: unique_tokens
#unique_tokens = set(word_tokenize(merged_df_AA5_head['reviewText'][0]))
unique_tokens = set(word_tokenize(allReviewText))

# Print the unique tokens result
print(unique_tokens)

# %%
# Import WordNetLemmatizer
from nltk.stem import WordNetLemmatizer
from collections import Counter
from nltk.corpus import stopwords

# %%
#In Python, searching a set is much faster than searching a list, 
# so convert the stop words to a set
stopword_list = set(stopwords.words("english"))

# %%
unique_tokens

# %%
# Retain alphabetic words: alpha_only
alpha_only = [t for t in unique_tokens if t.isalpha()]
alpha_only

# %%
# Remove all stop words: no_stops
no_stops = [t for t in alpha_only if t not in stopword_list]
no_stops

# %%
# Instantiate the WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# %%
# Lemmatize all tokens into a new list: lemmatized
lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in no_stops]
lemmatized

# %%
# Create the bag-of-words: bow
bow = Counter(lemmatized)
bow

# %%
# Print the 10 most common tokens
print(bow.most_common(10))

# %%
import spacy

# %%
#import en_core_web_sm
#nlp = en_core_web_sm.load()

# %%
from spacy.lang.en import English

# %%
# Instantiate the English model: nlp
#python -m spacy download en
nlp = spacy.load('en', tagger=False, parser=False, matcher=False)

# %%
# Create a new document: doc
#doc = nlp(merged_df_AA5_head['reviewText'][0])
doc = nlp(allReviewText)

# Print all of the found entities and their labels
for ent in doc.ents:
    print(ent.label_, ent.text)

# %%
doc = nlp(allReviewText)
# for token in doc:
#     print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop)
token_data = [(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop) for token in doc]
#token_data

tokendf = pd.DataFrame(token_data)
tokendf.columns = ['TEXT','LEMMA','POS','TAG','DEP','SHAPE','IS_ALPHA','IS_STOP']
tokendf

# %%
#CTRL + / for commenting/uncommenting lines
# def normalize_corpus(corpus):
#     normalized_corpus = []    
#     for text in corpus:
#         text = text.lower()
#         text = expand_contractions(text)
#         text = remove_characters(text)
#         tokens = tokenize_text(text)
#         tokens = remove_stopwords(tokens)
#         tokens = remove_repeated_characters(tokens)
#         tokens = correct(tokens)
#         tokens = Lemmatize_tokens(tokens)
#         text = ' '.join(tokens)
#         normalized_corpus.append(text)
                    
#     return normalized_corpus

# %%
nc = normalize_corpus(allReviewText)
nc

# %%
# sns.style = sns.set()

# _ = plt.hist(versicolor_petal_length)

# plt.show()

# %% [markdown]
# ##############################################################################################################################

# %% [markdown]
# ###### Working with entire dataset now

# %%
 df_RT_AA5.columns = [' reviewerID','asin','overall','unixReviewTime']

# %%
df_RT_AA5.shape

# %%
merged_df_AA5_wholeinner = pd.merge(df_AA5, df_RT_AA5, how='inner')

# %%
merged_df_AA5_wholeinner.shape

# %%
print(merged_df_AA5_wholeinner.head())

# %%
merged_df_AA5_wholeouter = pd.merge(df_AA5, df_RT_AA5, how='outer')
merged_df_AA5_wholeouter.shape
print(merged_df_AA5_wholeouter.head())

# %%
merged_df_AA5_wholeouter.shape

# %%
merged_df_AA5_wholeouter.isnull().values.any()

# %%
merged_df_AA5_wholeouter.isnull().values.count

# %%
merged_df_AA5_wholeouter.describe

# %%
merged_df_AA5_wholeouter.isnull().sum().sum()

# %%
# %pylab

# %%
# %pylab inline

# %%
plot

# %%
plt.plot(merged_df_AA5_wholeouter['overall'])

# %%
plt.hist(merged_df_AA5_wholeouter['overall'])
plt.show

# %%
merged_df_AA5_wholeouter['overall'].value_counts()

# %%
fig = plt.figure()

# %%
ax = fig.add.subplot(111)

# %%
ax = fig.add_subplot(111)

# %%
import numpy as np
fig, ax = plt.subplots()
ax.scatter(np.linspace(-1, 1, 10974305), merged_df_AA5_wholeouter['overall'],color = 'darkgreen', marker='^')

# %%
import numpy as np

sus1 = (merged_df_AA5_wholeouter['helpful'].str[1] != 0.0) & (merged_df_AA5_wholeouter['helpful'].dropna()) 
# Create a DataFrame with the suspicious row: susmerged_df_AA5['helpful'].str[1] != 0.0pect
suspect = merged_df_AA5_wholeouter.loc[sus1]
#print(suspect['helpful'])
#print(suspect)
merged_df_AA5_wholeouter['helpfulpercentage'] = (np.divide(suspect['helpful'].str[0],suspect['helpful'].str[1])* 100).astype(np.int64)
merged_df_AA5_wholeouter['helpful_numerator'] = suspect['helpful'].str[0].astype(np.int64)
merged_df_AA5_wholeouter['helpful_denominator'] = suspect['helpful'].str[1].astype(np.int64)

def calculate_charlen(row):
    return len(row['reviewText'])
sus = (merged_df_AA5_wholeouter['reviewText'].notnull())
# Create a DataFrame with the suspicious row: susmerged_df_AA5['helpful'].str[1] != 0.0pect
suspect = merged_df_AA5_wholeouter[sus]
merged_df_AA5_wholeouter['charCount_reviewText'] = suspect.apply(calculate_charlen,axis=1)
#merged_df_AA5_wholeouter       

def calculate_wordcount(row):
    return len(row['reviewText'].split())
sus1 = (merged_df_AA5_wholeouter['reviewText'].notnull())
# Create a DataFrame with the suspicious row: susmerged_df_AA5['helpful'].str[1] != 0.0pect
suspect1 = merged_df_AA5_wholeouter[sus1]
merged_df_AA5_wholeouter['wordCount_reviewText'] = suspect1.apply(calculate_charlen,axis=1)
merged_df_AA5_wholeouter 
#print(merged_df_AA5_wholeouter.dropna())

fig, ax = plt.subplots()
ax.scatter(merged_df_AA5_wholeouter.dropna()['wordCount_reviewText'],merged_df_AA5_wholeouter.dropna()['overall'],color = 'darkgreen', marker='^')
plt.title("Word Count vs Overall Score")
plt.xlabel("Word Count")
plt.ylabel("Overall Score")
plt.show

fig, ax = plt.subplots()
ax.scatter(merged_df_AA5_wholeouter.dropna()['charCount_reviewText'],merged_df_AA5_wholeouter.dropna()['overall'],color = 'darkgreen', marker='^')
plt.title("Character Count vs Overall Score")
plt.xlabel("Character Count")
plt.ylabel("Overall Score")
plt.show

fig, ax = plt.subplots()
ax.scatter(merged_df_AA5_wholeouter.dropna()['helpful_denominator'],merged_df_AA5_wholeouter.dropna()['overall'],color = 'darkgreen', marker='^')
plt.title("Helpfull Total Reviews vs Overall Score")
plt.xlabel("Helpful Total Reviews")
plt.ylabel("Overall Score")
plt.show

# %%
plt.hist(merged_df_AA5_wholeouter['overall',])
plt.show

# %%
merged_df_AA5_wholeouter

# %%
print(merged_df_AA5_wholeouter['overall'][0])
print(merged_df_AA5_wholeouter['reviewText'][0])

# %%
import numpy as np

sus1 = (merged_df_AA5_wholeouter['helpful'].str[1] != 0.0) & (merged_df_AA5_wholeouter['helpful'].dropna()) & (merged_df_AA5_wholeouter['helpful'].str[1] > 2000)
# Create a DataFrame with the suspicious row: susmerged_df_AA5['helpful'].str[1] != 0.0pect
suspect = merged_df_AA5_wholeouter.loc[sus1]
#print(suspect['helpful'])
#print(suspect)
merged_df_AA5_wholeouter['helpfulpercentage'] = (divide(suspect['helpful'].str[0],suspect['helpful'].str[1])* 100).astype(int64)
merged_df_AA5_wholeouter['helpful_numerator'] = suspect['helpful'].str[0].astype(int64)
merged_df_AA5_wholeouter['helpful_denominator'] = suspect['helpful'].str[1].astype(int64)
#print(merged_df_AA5_wholeouter.dropna())
plt.plot(merged_df_AA5_wholeouter.dropna()['helpful_denominator'],merged_df_AA5_wholeouter.dropna()['overall'])

fig, ax = plt.subplots()
ax.scatter(merged_df_AA5_wholeouter.dropna()['helpful_denominator'],merged_df_AA5_wholeouter.dropna()['overall'],color = 'darkgreen', marker='^')

#x = np.arange(10)
#fig, ax = plt.subplots()
#ax.stackplot(x, merged_df_AA5_wholeouter.dropna()['helpfulpercentage'])
#ax.set_title('100 % stacked area chart')
#ax.set_ylabel('Percent (%)')
#ax.margins(0, 0) # Set margins to avoid "whitespace"

plt.show()

# %%
import numpy as np
fig, ax = plt.subplots()
ax.scatter(np.linspace(-1, 1, 10974305), merged_df_AA5_wholeouter['overall'],color = 'darkgreen', marker='^')

# %%
plt.show

# %%
import numpy as np
fig, ax = plt.subplots()
ax = merged_df_AA5_wholeouter['overall'].plot(kind='area', stacked=True, title='100 % stacked area chart')
plt.show

# %%
merged_df_AA5_wholeouter.columns

# %%
merged_df_AA5_wholeouter.groupby(['reviewerID','asin'])['overall'].mean()

# %%
merged_df_AA5_wholeouter.groupby('asin')['overall'].mean()

# %%
df_meta_AA5_wholeouter = merged_df_AA5_wholeouter.groupby('reviewerID')['overall'].mean()

# %%
df_meta_AA5_wholeouter.describe
